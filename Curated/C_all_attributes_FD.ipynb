# %%
import pandas as pd
import re
from ast import literal_eval
from tqdm import tqdm
from ftfy import fix_text
# from util import UnitConversion, mapping_list_values, perl_to_posix
from groupby_toolz import enrich_db, gcloud
pd.set_option('display.max_colwidth', None)
pd.options.display.max_rows = 500
from flashtext import KeywordProcessor
from groupby_toolz import enrich_db, gcloud
pd.set_option('display.max_colwidth', None)
pd.options.display.max_columns = None
pd.options.display.max_rows = 500
import ast
import warnings
warnings.filterwarnings('ignore')
from natsort import natsorted
def query_from_file(file_name, params):
    with open(f'{file_name}', mode='r') as f:
        text = f.read()
        query = text.format(**params)
        return enrich_db(query)
def re_extract(pattern, txt):
    matches = re.findall(pattern, txt)
    tmp_matches = []
    for match in matches:
        for tup in match:
            if tup != '':
                tmp_matches.append(tup)
    return list(set(tmp_matches))
import time
today = time.strftime("%Y_%m_%d")

import ast
def remove_duplicates(A):
    [A.pop(count) for count,elem in enumerate(A) if A.count(elem)!=1]
    return A

# importing the sys module
import sys        
 
# appending the directory of mod.py
# in the sys.path list
sys.path.append('C:/Users/groupby/Documents/GitHub/SQL Extract And Apply') 
from enrich_dimensions.rounds import rounds, rounding,re_extract, curate, round_string_float,reg_ex,clean_data#,rounding_kimball
from enrich_dimensions.params import parameters, query_from_file
from enrich_dimensions.query_file import query_from_file 
from enrich_dimensions.custom import custom_field 

def three(usa,reg):
    trip=fr'''(?i){reg}|()''' 
    usa['m_name']=usa['product_name'].apply(lambda x: re_extract(trip,str(x)))
    usa['m_desc']=usa['long_desc'].apply(lambda x: re_extract(trip,str(x)))
    usa['m_custom']=usa['custom_fields'].apply(lambda x: re_extract(trip,str(x)))
    imported=usa[(usa['m_name'].astype(str)!='[]')|(usa['m_desc'].astype(str)!='[]')|(usa['m_custom'].astype(str)!='[]')]
    impor=usa[(usa['m_name'].astype(str)=='[]')&(usa['m_desc'].astype(str)=='[]')&(usa['m_custom'].astype(str)=='[]')]
    print('values: '+str(len(imported)))
    print('no values: '+str(len(impor)))
    return imported,impor

def  range_app(num_lst):
    updated_labels = []
    for num in num_lst:
        num = float(num)
        for range_param, range_label in range_params.items():
            if len(range_param) == 1:
                if num >= range_param[0]:
                    updated_labels.append(range_label)
            else:
                if num >= range_param[0] and num <= range_param[1]:
                    updated_labels.append(range_label)
    return updated_labels

def remove_duplicates(A):
    [A.pop(count) for count,elem in enumerate(A) if A.count(elem)!=1]
    return A
    
    
import time
today = time.strftime("%Y_%m_%d")
print('Done')
# rounding(inside, 'Q:inside_diameter','a-eghj-lo-su-z*')

# .apply(lambda x: re.sub(r'(\s?(?<!")(?=\]))|("")','"',str(x))).apply(lambda x: re.sub(r'("")','"',str(x))).apply(lambda x: remove_duplicates([n.strip() for n in ast.literal_eval(x)])).apply(lambda x: natsorted(x)).apply(lambda x: re.sub(r'''(((?:"|')?\s?\,\s?(?!")(?:')?))''','","',str(x))).apply(lambda x: re.sub(r'''((?<=\[)\s?'\s?)|(\s?'\s?(?=\]))|(\s?'\s?(?=\,))|((?<=\,)\s?'\s?)''','"',str(x)))
# Out:
# Done

# %% [markdown]
# # BBBY Bed Bath and Beyond

# %%
print('bbby')
# Out:
# bbby

# %%
# Out:
# start
# 1088706

# %%
capacity (qt)
Room Coverage
Baby Food Volume
Daily Ice Production

# %%
x='capacity (qt)'
x.replace(' ','_').replace('(','_').replace(')','')
# Out:
# 'capacity__qt'

# %%
customer_id = '136'
customer_name='%familydollar%'
dateszs='2002-08-11'
attribut='diameter'
curation_col = f'Q:{attribut}'
params = {'customer_id': customer_id,
          'customer_name':customer_name,
         'dateszs':dateszs,
         'attribute':attribut}

print('start')
dfs = query_from_file(file_name='../query/curated_all_attributes_date_one_attribute.sql', params=params)
print(len(dfs))
dfz=dfs[dfs['resolution'].astype(str)!='rules']
print(len(dfz))
dfh=dfz[dfz['custom_fields'].astype(str)!='None']
# dfz=dfz[dfz['buckets'].astype(str)=='Conduit Fittings, Replacement Parts, & Accessories']
print(len(dfh))
custom_field_df=pd.json_normalize(dfh['custom_fields'])
df=pd.concat([dfh.drop('custom_fields', axis=1), custom_field_df], axis = 1)
print(len(df))
# Out:
# start
# 358
# 358
# 358
# 358

# %%
df['value'].explode().value_counts()
# print(len(df[df['value'].astype(str)!='n/a']))
# Out:
# Series([], Name: value, dtype: int64)

# %%
print(len(df))
pat='''(?i)((?<=\w)(?<!st)(?<!\d)\.)'''
df['match']=df['value'].apply(lambda x: re_extract(pat,str(x)))
qt=df[df['match'].astype(str)!='[]']
print(len(qt))
# Out:
# 6598
# 1448

# %%
qt['value'].explode().value_counts()
df[curation_col]=df['value'].apply(lambda x: re.sub(r'(?i)((?<=\w)(?<!st)(?<!\d)\.)','',str(x)))
df[curation_col].explode().value_counts()
# Out:
# n/a                      5150
# 400-499 sq ft             504
# 500 and Greater sq ft     434
# Under 300 sq ft           385
# 300-399 sq ft             125
# Name: Q:room_coverage, dtype: int64

# %%
match=df[(df['value'].astype(str)!='nan')&(df['value'].astype(str)!='n/a')]
match[curation_col].explode().value_counts()
match_qt=match[['external_id',curation_col]]
match_qt
# Out:
#       external_id         Q:capacity_qt
# 0        65631416  ["12 qt or Greater"]
# 12715    69786932      12 qt or Greater
# 12716    69786933      12 qt or Greater
# 12717    69786934      12 qt or Greater
# 13302    69540631      12 qt or Greater
# ...           ...                   ...
# 67852    69880957            4 - 5.9 qt
# 67869   200171541            6 - 7.9 qt
# 67889    69837405            6 - 7.9 qt
# 67890    69837407            6 - 7.9 qt
# 67891    69837415            6 - 7.9 qt
#
# [678 rows x 2 columns]

# %%
# imported['Q:origin']=''
# match_na_re_curates=imported[['external_id','Q:origin']]

def get_df_name(df):
    name =[x for x in globals() if globals()[x] is df][0]
    return name
def looks_good(customer, matches): 
    drive_path = f'G:/Shared drives/GroupBy Public/Customer Success/.Enrich/Platform Upload Trail/{customer}/_Ready For Upload' 
    matches.to_csv(f'{drive_path}/Bed Bath & Beyond --{get_df_name(matches)}-match_qt-{today}.csv',index=False) 
looks_good('Bed Bath & Beyond',match_qt)

# %%
customer_id = '135'
customer_name='%dollartree%'
dateszs='2022-11-01'
dateszsz=today
params = {'customer_id': customer_id,
          'customer_name':customer_name,
         'dateszs':dateszs,
         'dateszsz':dateszsz}
print('start')
# dfs = query_from_file(file_name='../query/curated_all_attributes_date.sql', params=params)
dfs = query_from_file(file_name='../query/curated_all_attributes_date_dates.sql', params=params)
print(len(dfs))

# custom_field_df=pd.json_normalize(dfs['custom_fields'])
# df=pd.concat([dfs.drop('custom_fields', axis=1), custom_field_df], axis = 1)
# print(len(df))
# Out:
# start
# 7573

# %%
# df=dfs[dfs['resolution'].astype(str)=='standard']

def three(usa,reg):
    print('Start')
    trip=fr'''(?i){reg}|()''' 
    
    usa['m_name']=usa['product_name'].apply(lambda x: re_extract(trip,str(x)))
    usa['m_desc']=usa['long_desc'].apply(lambda x: re_extract(trip,str(x)))
    usa['m_custom']=usa['custom_fields'].apply(lambda x: re_extract(trip,str(x)))
    main=usa[(usa['m_name'].astype(str)!='[]')]
    middle=usa[(usa['m_name'].astype(str)=='[]')&((usa['m_desc'].astype(str)!='[]')|(usa['m_custom'].astype(str)!='[]'))]
    na=usa[(usa['m_name'].astype(str)=='[]')&(usa['m_desc'].astype(str)=='[]')&(usa['m_custom'].astype(str)=='[]')]
    
    print('')
    print('values: '+str(len(main)))
    print('No name but call outs: '+str(len(middle)))
    print('no values: '+str(len(na)))
    print('')
    return main,middle,na

# %%
# not indoor/outdoor, occasion, setsize, size, 
df=dfs[(dfs['attribute'].astype(str)!='keywords')&(dfs['resolution'].astype(str)!='rules')]
print(len(df))
df['attribute'].explode().value_counts()
# Out:
# 7433
# product_type               1154
# color                       852
# material                    748
# package_quantity            712
# features                    635
# length                      445
# width                       333
# occasion                    317
# count                       281
# height                      253
# volume_oz                   212
# flavor                      169
# care                        159
# diameter                    136
# pencil_type                 125
# marker_type                 124
# pen_type                    124
# concern                     117
# product_form                 90
# capacity_oz                  88
# page_count                   59
# scent                        53
# key_ingredient               42
# roll_length                  40
# maximum_burn_time            39
# maximum_recommended_age      33
# minimum_recommended_age      32
# flower_type                  20
# weight                       11
# weight_capacity               8
# diopter                       6
# cord_length                   4
# capacity_gal                  3
# grit                          3
# roast                         2
# wattage                       1
# lumens                        1
# voltage                       1
# bulb_color                    1
# Name: attribute, dtype: int64

# %%
pat='''(?i)(\d+.{0,3}(?:oz|ounce))'''
x,y=three(sets,pat)
# Out:
# values: 368
# no values: 101

# %%
sets['buckets'].explode().value_counts()
# Out:
# Nail Polishes & Adornment                    75
# Oral Cleaning Products                       47
# Chips & Crackers                             25
# Fruits, Vegetables, & Fungi                  25
# Foundations & Tinted Moisturizers            24
# Lotions & Moisturizers                       18
# Prepared Soft Drinks & Water                 18
# Cookies & Biscuits                           17
# Dish Cleaners                                17
# Herbs, Spices, & Seasonings                  16
# Pain Relievers & Fever Reducers              16
# Lipsticks, Glosses, & Stains                 13
# Concealers & Color Correctors                12
# Prepared Juices                              12
# Pancake, Waffle, & Baking Mixes              11
# Deodorants & Antiperspirants                 10
# Cereals & Pseudocereals                       9
# Soups & Broths                                9
# Sauces, Pastes, & Gravies                     9
# Vitamins, Minerals, & Dietary Supplements     8
# Adhesives & Glues                             8
# Spreads & Dips                                8
# Water Flavorings/Enhancers                    7
# Seed & Nut Butters                            6
# Unprepared Coffee                             6
# Vinegars & Dressings                          6
# Mascara                                       5
# Facial Cleansers & Cosmetic Removers          5
# Face & Body Oils                              4
# Bronzer, Contour, & Highlighter               4
# Olives, Pickles & Relishes                    4
# Eyebrow Products                              4
# Oils (Edible)                                 3
# Salts                                         2
# Pasta & Noodles                               2
# Mouth Washes, Rinses, & Sprays                2
# Milk & Milk Alternatives                      1
# Exfoliants & Masks                            1
# Name: buckets, dtype: int64

# %%
def bucketz(name,bucket,range_string,regex):
    # bucket gum
    Chocolate=name[name['buckets'].astype(str)==bucket]
    print(len(Chocolate))

    metric='oz'


    range_params = {}
    for range_entry in range_string.split('\n'):
        range_nums = re.findall('\d+', range_entry)
        if len(range_nums) > 0: 
            range_params[tuple(map(int, range_nums))] = range_entry.strip()


    def  range_app(num_lst):
        updated_labels = []
        for num in num_lst:
            num = float(num)
            for range_param, range_label in range_params.items():
                if len(range_param) == 1:
                    if num >= range_param[0]:
                        updated_labels.append(range_label)
                else:
                    if num >= range_param[0] and num <= range_param[1]:
                        updated_labels.append(range_label)
        return updated_labels

    def remove_duplicates(A):
        [A.pop(count) for count,elem in enumerate(A) if A.count(elem)!=1]
        return A

    Chocolate[curation_col]=Chocolate['m_name'].apply(lambda x: re.sub(fr'(?i){regex}','',str(x))).apply(lambda x: remove_duplicates([n.strip() for n in ast.literal_eval(x)])).apply(range_app).apply(lambda x: re.sub(r"\['",'["',str(x))).apply(lambda x: re.sub(r"'\]",'"]',str(x))).apply(lambda x: re.sub(r"'\s?,\s?'",'","',str(x))).apply(lambda x: re.sub(r"'\[",'[',str(x))).apply(lambda x: re.sub(r"\]'",']',str(x))).apply(lambda x: re.sub(r'\,\s',',',str(x))).apply(lambda x: remove_duplicates([n.strip() for n in ast.literal_eval(x)])).apply(lambda x: '["'+'","'.join(natsorted(x))+'"]').apply(lambda x: re.sub(r"\['",'["',str(x))).apply(lambda x: re.sub(r"'\]",'"]',str(x))).apply(lambda x: re.sub(r"'\s?,\s?'",'","',str(x))).apply(lambda x: re.sub(r"'\[",'[',str(x))).apply(lambda x: re.sub(r"\]'",']',str(x)))
    return Chocolate

# %%
sets=df[df['attribute'].astype(str)=='package_quantity']
na=sets[sets['value'].astype(str)=='n/a']
print(len(sets))
print(len(na))
size=sets[sets['value'].astype(str)!='n/a']
print(len(size))

trip=r'''(?i)(\d+(?:\.\d+).{0,3}(?:oz|ounce))|()'''
sets['m_name']=sets['product_name'].apply(lambda x: re_extract(trip,str(x)))
sets['m_long']=sets['long_desc'].apply(lambda x: re_extract(trip,str(x)))
trip=fr'''(?i)((?<=volume_dimension\'\:)\s'\d+(?:\.\d+)?\s?(?:(?:.?fl.?)?oz)?)|()'''
sets['m_custom']=sets['custom_fields'].apply(lambda x: re_extract(trip,str(x)))
# Out:
# 712
# 195
# 517

# %%
sets
# Out:
#              attribute                                  buckets  bucket_id  \
# 285   package_quantity  Writing/Design Implements & Accessories       8477
# 286   package_quantity  Writing/Design Implements & Accessories       8477
# 287   package_quantity  Writing/Design Implements & Accessories       8477
# 288   package_quantity  Writing/Design Implements & Accessories       8477
# 289   package_quantity  Writing/Design Implements & Accessories       8477
# ...                ...                                      ...        ...
# 7526  package_quantity                           Action Figures       9292
# 7527  package_quantity                           Action Figures       9292
# 7528  package_quantity                           Action Figures       9292
# 7530  package_quantity                           Action Figures       9292
# 7549  package_quantity                           Action Figures       9292
#
#           value customer_name external_id  \
# 285      2-Pack    dollartree      120569
# 286      2-Pack    dollartree      120990
# 287      2-Pack    dollartree      172077
# 288      2-Pack    dollartree      172078
# 289      2-Pack    dollartree      178322
# ...         ...           ...         ...
# 7526        n/a    dollartree      305805
# 7527        n/a    dollartree      328543
# 7528        n/a    dollartree      333124
# 7530        n/a    dollartree      362505
# 7549  Multipack    dollartree      354928
#
#                                                   product_name  \
# 285                  Promarx Retractable Gel Pens, 2-ct. Packs
# 286      Jot Plastic Pencil and Crayon Sharpeners, 2-ct. Packs
# 287   Inc. R-2 Rollerball Cap Pens with Black Ink, 2-ct. Packs
# 288                  Inc. R-2 Blue Roller Ball Cap Pens, 2-ct.
# 289          Inc. Optimus Felt Tip Pens with Caps, 2-ct. Packs
# ...                                                        ...
# 7526               Minions Character Figurines, 2.375x1.25 in.
# 7527         Super Stretch Ninja and Soldier Toys, 6x3x0.4 in.
# 7528                        Surprise Blind Balls(TM), 2.25 in.
# 7530                             Puppy in My Pocket Blind Pack
# 7549                           Transformers Figurines, 4.5-in.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         long_desc  \
# 285                                                                                                                                                                                                                                                                                                                                Gel pens provide super smooth writing while comfort grip helps reduce hand fatigue. They come in 2-ct. packs and the ink color is assorted between black and blue. Great for office buildings, schools, homes, and bookstores.
# 286                                                                                                                                           Keep your pencils and crayons sharpened and ready for drawing, coloring, and more! Each pack includes one pencil sharpener and one crayon sharpener assorted among green, orange, pink, blue, white, and black. These 2-ct. packs Jot(TM) Plastic Pencil and Crayon Sharpeners are a back-to-school essential - perfect for your elementary school classroom, art studio, or craft space. Colors will vary by pack.
# 287                                                                                                                                                                                                                                                                                                                                                               Controlled ink flow system helps you write smoothly and the rubber grip by the pen tip provides maximum control! Never again be left without something to write your thoughts and to do's down.
# 288   Write with the style and smoothness you deserve thanks to these pens! Each pack contains two high-quality blue pens with a large body and rubber grip for increased comfortability and control. The controlled ink flow system helps you write smoothly and effortlessly without all the excess ink and globbing that is common with other pens. Great for back-to-school lists, stocking stuffers, students, teachers, office workers, artists, crafters, and more. Get a writing experience like no other with Inc.(R) R-2(TM) Blue Roller Ball Cap Pens!
# 289                                                                                                                                                                                                                                           Fine strokes in deep black or blue ink are perfect for everything from taking notes to signing checks! Each pen features felt tips and bleed-free ink. They come in 2-ct. packs that you can use to write letters, reminders, lists, and more. Great item for offices, schools, churches, bookstores, and the home.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 7526                                                                                                                                                             You love them, your Mom loves them, your kids love them, your sister's kids love them, and you absolutely have to have them! These 2.375-in. tall figurines are Minion lovers' dreams. Display them in bedrooms, playrooms, office spaces, and more. It will put smiles on faces each time they are looked upon. The Minions(TM) figurines come assorted among the 5 fun designs shown. Ages 4+.
# 7527                                                                                                                                                                                                                                                                                                                              One fun way to enjoy the more simple things in life is with these super stretchy toys that are perfect for kids! They stretch far beyond their original shapes and are assorted between 2 shapes: ninjas and soldiers. Ages 3+.
# 7528                                                                                                                                        Add a little mystery to play time with these hot pink Surprise Blind Balls?! Crack these 2.25-in. balls open to reveal a unique prize figurine assorted among dinosaurs, unicorns, pandas, cacti reading "sunny day," frogs, and owls. Each figure measures about 1x0.5-in. and has a little loop on the top to attach a key ring. Great for party favors, prize boxes, rewards for good behavior, and more! Ages 4+.
# 7530                                                                                                                                                                                                                                                                                                                                       Find yourself a new best friend with these Puppy in My Pocket(R) Blind Packs. Each pack contains 1 of 10 possible characters so collect them all. Ages 4+ Small parts, not intended for children under 3 years of age.
# 7549                                                                                                                                                                                                                                                                                                              Pit Autobots Optimus Prime and Bumblebee against the deviousness of the Decepticons Starscream, Soundwave, and the mastermind Megatron. These 4.5-in. Transformers(TM) Figurines are sure to bring no end of fun as they battle it out. Ages 3+
#
#      curated_date resolution  curation_tasks.curated_by  \
# 285    2022-12-23   standard                        763
# 286    2022-12-23   standard                        661
# 287    2022-12-23   standard                       1006
# 288    2022-12-23   standard                        433
# 289    2022-12-23   standard                       1006
# ...           ...        ...                        ...
# 7526   2022-12-29   standard                        658
# 7527   2022-12-29   standard                        658
# 7528   2022-12-29   standard                        660
# 7530   2022-12-29   standard                        658
# 7549   2022-12-29   standard                        890
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                custom_fields  \
# 285                                                                                                                                                                                                                                                                                                                                {'name': 'Promarx Retractable Gel Pens, 2-ct. Packs', 'image_file': 'https://www.dollartree.com/ccstore/v1/images/?source=/file/v3414284165430845942/products/120569.jpg&height=940&width=940', 'description': 'Gel pens provide super smooth writing while comfort grip helps reduce hand fatigue. They come in 2-ct. packs and the ink color is assorted between black and blue. Great for office buildings, schools, homes, and bookstores.', 'meta_keywords': 'Promarx Retractable Gel Pens, 2-ct. Packs', 'width_dimension': '3.375 in', 'length_dimension': '0.625 in', 'weight_dimension': '0 oz', 'assortment_by_style_color': 'Even Assortment'}
# 286                                                                                                                   {'name': 'Jot Plastic Pencil and Crayon Sharpeners, 2-ct. Packs', 'image_file': 'https://www.dollartree.com/ccstore/v1/images/?source=/file/v4491434037501799337/products/120990.jpg&height=940&width=940', 'description': 'Keep your pencils and crayons sharpened and ready for drawing, coloring, and more! Each pack includes one pencil sharpener and one crayon sharpener assorted among green, orange, pink, blue, white, and black. These 2-ct. packs Jot(TM) Plastic Pencil and Crayon Sharpeners are a back-to-school essential - perfect for your elementary school classroom, art studio, or craft space. Colors will vary by pack.', 'meta_keywords': 'Jot Plastic Pencil and Crayon Sharpeners, 2-ct. Packs', 'width_dimension': '1.875 in', 'length_dimension': '1.125 in', 'weight_dimension': '0 oz', 'assortment_by_style_color': 'Even Assortment'}
# 287                                                                                                                                                                                                                                                                                                                                                                                                             {'name': 'Inc. R-2 Rollerball Cap Pens with Black Ink, 2-ct. Packs', 'image_file': 'https://www.dollartree.com/ccstore/v1/images/?source=/file/v6208401970247288312/products/172077.jpg&height=940&width=940', 'description': 'Controlled ink flow system helps you write smoothly and the rubber grip by the pen tip provides maximum control! Never again be left without something to write your thoughts and to do's down.', 'meta_keywords': 'Inc. R-2 Rollerball Cap Pens with Black Ink, 2-ct. Packs', 'width_dimension': '0.5 in.', 'length_dimension': '0.625 in.'}
# 288   {'name': 'Inc. R-2 Blue Roller Ball Cap Pens, 2-ct.', 'image_file': 'https://www.dollartree.com/ccstore/v1/images/?source=/file/v3386634455940368917/products/172078.jpg&height=940&width=940', 'description': 'Write with the style and smoothness you deserve thanks to these pens! Each pack contains two high-quality blue pens with a large body and rubber grip for increased comfortability and control. The controlled ink flow system helps you write smoothly and effortlessly without all the excess ink and globbing that is common with other pens. Great for back-to-school lists, stocking stuffers, students, teachers, office workers, artists, crafters, and more. Get a writing experience like no other with Inc.(R) R-2(TM) Blue Roller Ball Cap Pens!', 'meta_keywords': 'Inc. R-2 Blue Roller Ball Cap Pens, 2-ct.', 'width_dimension': '2.738 in', 'length_dimension': '0.738 in', 'weight_dimension': '0 oz', 'assortment_by_style_color': 'Even Assortment'}
# 289                                                                                                                                                                                                                           {'name': 'Inc. Optimus Felt Tip Pens with Caps, 2-ct. Packs', 'image_file': 'https://www.dollartree.com/ccstore/v1/images/?source=/file/v8112518332601295221/products/178322.jpg&height=940&width=940', 'description': 'Fine strokes in deep black or blue ink are perfect for everything from taking notes to signing checks! Each pen features felt tips and bleed-free ink. They come in 2-ct. packs that you can use to write letters, reminders, lists, and more. Great item for offices, schools, churches, bookstores, and the home.', 'meta_keywords': 'Inc. Optimus Felt Tip Pens with Caps, 2-ct. Packs', 'width_dimension': '2.746 in', 'length_dimension': '0.624 in', 'weight_dimension': '0 oz', 'assortment_by_style_color': 'Even Assortment'}
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 7526                                                                                                                                                               {'name': 'Minions Character Figurines, 2.375x1.25 in.', 'image_file': 'https://www.dollartree.com/ccstore/v1/images/?source=/file/v8430559642640880673/products/305805.jpg&height=940&width=940', 'description': 'You love them, your Mom loves them, your kids love them, your sister's kids love them, and you absolutely have to have them! These 2.375-in. tall figurines are Minion lovers' dreams. Display them in bedrooms, playrooms, office spaces, and more. It will put smiles on faces each time they are looked upon. The Minions(TM) figurines come assorted among the 5 fun designs shown. Ages 4+.', 'meta_keywords': 'Minions Character Figurines, 2.375x1.25 in.', 'width_dimension': '2 in', 'length_dimension': '1 in', 'weight_dimension': '0 oz', 'assortment_by_style_color': 'Uneven Assortment'}
# 7527                                                                                                                                                                                                                                                                                                                    {'name': 'Super Stretch Ninja and Soldier Toys, 6x3x0.4 in.', 'image_file': 'https://www.dollartree.com/ccstore/v1/images/?source=/file/v6720333000646959027/products/328543.jpg&height=940&width=940', 'description': 'One fun way to enjoy the more simple things in life is with these super stretchy toys that are perfect for kids! They stretch far beyond their original shapes and are assorted between 2 shapes: ninjas and soldiers. Ages 3+.', 'meta_keywords': 'Super Stretch Ninja and Soldier Toys, 6x3x0.4 in.', 'width_dimension': '3 in', 'length_dimension': '6 in', 'weight_dimension': '0 oz', 'assortment_by_style_color': 'Uneven Assortment'}
# 7528                                                                                                                                                                                                                                                               {'name': 'Surprise Blind Balls(TM), 2.25 in.', 'image_file': 'https://www.dollartree.com/ccstore/v1/images/?source=/file/v6632907508616427640/products/333124.jpg&height=940&width=940', 'description': 'Add a little mystery to play time with these hot pink Surprise Blind Balls?! Crack these 2.25-in. balls open to reveal a unique prize figurine assorted among dinosaurs, unicorns, pandas, cacti reading "sunny day," frogs, and owls. Each figure measures about 1x0.5-in. and has a little loop on the top to attach a key ring. Great for party favors, prize boxes, rewards for good behavior, and more! Ages 4+.', 'meta_keywords': 'Surprise Blind Balls(TM), 2.25 in.', 'diameter_dimension': '2.25 in.'}
# 7530                                                                                                                                                                                                                                                                                                                                                                     {'name': 'Puppy in My Pocket Blind Pack', 'image_file': 'https://www.dollartree.com/ccstore/v1/images/?source=/file/v2633991529434680827/products/362505.jpg&height=940&width=940', 'description': 'Find yourself a new best friend with these Puppy in My Pocket(R) Blind Packs. Each pack contains 1 of 10 possible characters so collect them all. Ages 4+ Small parts, not intended for children under 3 years of age.', 'meta_keywords': 'Puppy in My Pocket Blind Pack', 'width_dimension': '0 in', 'length_dimension': '0 in', 'weight_dimension': '0 oz', 'assortment_by_style_color': 'Uneven Assortment'}
# 7549                                                                                                                                                                                                                                                                                                                                  {'name': 'Transformers Figurines, 4.5-in.', 'image_file': 'https://www.dollartree.com/ccstore/v1/images/?source=/file/v6378958962104325709/products/354928.jpg&height=940&width=940', 'description': 'Pit Autobots Optimus Prime and Bumblebee against the deviousness of the Decepticons Starscream, Soundwave, and the mastermind Megatron. These 4.5-in. Transformers(TM) Figurines are sure to bring no end of fun as they battle it out. Ages 3+', 'meta_keywords': 'Transformers Figurines, 4.5-in.', 'width_dimension': '3.25 in', 'length_dimension': '1.25 in', 'weight_dimension': '0 lb', 'assortment_by_style_color': 'Uneven Assortment'}
#
#      m_name m_long m_custom
# 285      []     []       []
# 286      []     []       []
# 287      []     []       []
# 288      []     []       []
# 289      []     []       []
# ...     ...    ...      ...
# 7526     []     []       []
# 7527     []     []       []
# 7528     []     []       []
# 7530     []     []       []
# 7549     []     []       []
#
# [712 rows x 15 columns]

# %%
# vol=sets[((sets['m_name'].astype(str)!='[]')|(sets['m_custom'].astype(str)!='[]'))&((sets['value'].astype(str)!='n/a'))]
# na=sets[(sets['m_name'].astype(str)=='[]')&(sets['m_long'].astype(str)=='[]')&(sets['m_custom'].astype(str)=='[]')&(sets['value'].astype(str)!='n/a')]
# print(len(vol))
# print(len(na))
# Out:
# 203
# 194

# %%
#     range_string = """
#     0 - 0.25 oz
#     0.26 - 0.5 oz
#     0.51 - 0.75 oz
#     0.76 - 1.0 oz
#     1.1 - 1.5 oz
#     1.6 - 2.0 oz
#     2.1 - 2.5 oz
#     2.6 - 3.0 oz
#     Greater than 3.0 oz
#     n/a
#     """

# %%
# att=bucketz(sets,'Oral Cleaning Products',range_string,'''((?:\-|\s)?(?:(?:fl\.?\s?|fluid\.?\s?)?oz|(?:fl\.?\s?|fluid\.?\s?)?ounce?))''')
# match_Chocolate=Chocolate[['external_id',curation_col]]
# Out:
# 47

# %%
# import re


# range_string = """
# 0 - 0.25 oz
# 0.26 - 0.5 oz
# 0.51 - 0.75 oz
# 0.76 - 1.0 oz
# 1.1 - 1.5 oz
# 1.6 - 2.0 oz
# 2.1 - 2.5 oz
# 2.6 - 3.0 oz
# Greater than 3.0 oz
#  """

# range_params = {}
# for range_entry in range_string.split('\n'):
#     range_nums = re.findall('\d+', range_entry)
#     if len(range_nums) > 0: 
#         range_params[tuple(map(int, range_nums))] = range_entry.strip()


# def  range_app(num_lst):
#     print(num_lst)
#     updated_labels = []
#     for num in num_lst:
#         num = float(num)
#         for range_param, range_label in range_params.items():
#             print(range_param)
#             if len(range_param) == 1:
#                 if num >= range_param[0]:
#                     updated_labels.append(range_label)
#             else:
#                 if num >= range_param[0] and num <= range_param[1]:
#                     updated_labels.append(range_label)
#     return updated_labels

# %%
# att[att['m_name'].astype(str)=="['0.44-oz']"]['m_name'].apply(lambda x: re.sub(fr'''(?i)((?:\-|\s)?(?:(?:fl\.?\s?|fluid\.?\s?)?oz|(?:fl\.?\s?|fluid\.?\s?)?ounc))''','',str(x))).apply(lambda x: remove_duplicates([n.strip() for n in ast.literal_eval(x)])).apply(range_app)
# sets[sets['m_name'].astype(str)=='''['3.5 oz']''']['m_name'].apply(lambda x: re.sub(r'''(?i)((?:\-|\s)?(?:(?:fl\.?\s?|fluid\.?\s?)?oz|(?:fl\.?\s?|fluid\.?\s?)?ounc))''','',str(x))).apply(lambda x: remove_duplicates([n.strip() for n in ast.literal_eval(x)])).apply(range_app)

# %%
sets['m_name'].explode().value_counts()
# Out:
# 14.5 oz      7
# 3.5 oz       4
# 0.42 oz      4
# 0.14 oz      4
# 2.5 oz       4
# 4.8 oz       4
# 15.25 oz     4
# 5.5 oz       3
# 6.0 Ounce    3
# 2.5 Ounce    3
# 18.8 oz      3
# 1.93 oz      3
# 12.2 oz      2
# 0.42-oz      2
# 1.48 oz      2
# 6.5 oz       2
# 4.6 ounce    2
# 10.5 oz      2
# 18.6 oz      2
# 0.11 oz      2
# 0.3 oz       2
# 12.5 oz      2
# 13.5-oz      2
# 8.5 oz       2
# 7.5 oz       1
# 3.17 oz      1
# 1.58 oz      1
# 15.5 oz      1
# 2.2 oz       1
# 5.1 oz       1
# 1.6 oz       1
# 33.8 oz      1
# 7.2 oz       1
# 32.5 oz      1
# 33.5 oz      1
# 2.8-oz       1
# 1.23 oz      1
# 9.9 oz       1
# 2.6 oz       1
# 5.4 oz       1
# 0.43 oz      1
# 6.1-oz       1
# 4.3-oz       1
# 4.5-oz       1
# 0.2 oz       1
# 17.6 oz      1
# 3.8 oz       1
# 14.3 oz      1
# 0.1 oz       1
# 5.3 oz       1
# 16.3 oz      1
# 0.87 oz      1
# 1.11-oz      1
# 14.75 oz     1
# 19.1 oz      1
# 1.4 oz       1
# 12.25 oz     1
# 16.9 oz      1
# 0.125 oz     1
# 3.3-oz       1
# 6.52 oz      1
# 0.32 oz      1
# 3.2 ounce    1
# 0.27 oz      1
# 8.75 oz      1
# 7.1 oz       1
# 0.18 oz      1
# 0.44-oz      1
# 1.76 oz      1
# 14.4 oz      1
# 4.65 oz      1
# 5.5-oz       1
# 10.3 oz      1
# 2.65 oz      1
# 16.25 oz     1
# 13.6 oz      1
# 30.6 oz      1
# 21.6 oz      1
# 2.25 oz      1
# 2.7 oz       1
# 17.2 oz      1
# 1.1-oz       1
# 20.5 oz      1
# 0.26 oz      1
# 22.9 oz      1
# 33.9 oz      1
# 0.07 oz      1
# 0.33 oz      1
# 11.5 oz      1
# 31.58-oz     1
# 12.7 oz      1
# 2.7oz        1
# 2.8 oz       1
# 1.35-oz      1
# 0.49 oz      1
# 30.5 oz      1
# 13.8 oz      1
# 10.25 oz     1
# 17.8 oz      1
# 4.2 ounce    1
# 1.93-oz      1
# 18.3 oz      1
# Name: m_name, dtype: int64

# %%
print(len(sets[sets['value'].astype(str)!='n/a']))
sets[sets['value'].astype(str)!='n/a']
# Out:
# 398
#       attribute                                    buckets  bucket_id  \
# 168   volume_oz                 Water Flavorings/Enhancers       8863
# 169   volume_oz                 Water Flavorings/Enhancers       8863
# 170   volume_oz                 Water Flavorings/Enhancers       8863
# 171   volume_oz                 Water Flavorings/Enhancers       8863
# 172   volume_oz                 Water Flavorings/Enhancers       8863
# 173   volume_oz                 Water Flavorings/Enhancers       8863
# 356   volume_oz  Vitamins, Minerals, & Dietary Supplements       7363
# 357   volume_oz  Vitamins, Minerals, & Dietary Supplements       7363
# 358   volume_oz  Vitamins, Minerals, & Dietary Supplements       7363
# 359   volume_oz  Vitamins, Minerals, & Dietary Supplements       7363
# 360   volume_oz  Vitamins, Minerals, & Dietary Supplements       7363
# 361   volume_oz  Vitamins, Minerals, & Dietary Supplements       7363
# 362   volume_oz  Vitamins, Minerals, & Dietary Supplements       7363
# 410   volume_oz                       Vinegars & Dressings       8046
# 411   volume_oz                       Vinegars & Dressings       8046
# 412   volume_oz                       Vinegars & Dressings       8046
# 418   volume_oz                       Vinegars & Dressings       8046
# 419   volume_oz                       Vinegars & Dressings       8046
# 464   volume_oz                          Unprepared Coffee       7581
# 465   volume_oz                          Unprepared Coffee       7581
# 466   volume_oz                          Unprepared Coffee       7581
# 467   volume_oz                          Unprepared Coffee       7581
# 469   volume_oz                          Unprepared Coffee       7581
# 470   volume_oz                          Unprepared Coffee       7581
# 790   volume_oz                             Spreads & Dips       8047
# 794   volume_oz                             Spreads & Dips       8047
# 798   volume_oz                             Spreads & Dips       8047
# 800   volume_oz                             Spreads & Dips       8047
# 809   volume_oz                             Spreads & Dips       8047
# 810   volume_oz                             Spreads & Dips       8047
# 811   volume_oz                             Spreads & Dips       8047
# 812   volume_oz                             Spreads & Dips       8047
# 820   volume_oz                             Soups & Broths       8025
# 831   volume_oz                             Soups & Broths       8025
# 832   volume_oz                             Soups & Broths       8025
# 833   volume_oz                             Soups & Broths       8025
# 834   volume_oz                             Soups & Broths       8025
# 839   volume_oz                             Soups & Broths       8025
# 840   volume_oz                             Soups & Broths       8025
# 841   volume_oz                             Soups & Broths       8025
# 842   volume_oz                             Soups & Broths       8025
# 917   volume_oz                         Seed & Nut Butters       8048
# 919   volume_oz                         Seed & Nut Butters       8048
# 920   volume_oz                         Seed & Nut Butters       8048
# 926   volume_oz                         Seed & Nut Butters       8048
# 929   volume_oz                         Seed & Nut Butters       8048
# 930   volume_oz                         Seed & Nut Butters       8048
# 965   volume_oz                  Sauces, Pastes, & Gravies       8050
# 968   volume_oz                  Sauces, Pastes, & Gravies       8050
# 969   volume_oz                  Sauces, Pastes, & Gravies       8050
# 970   volume_oz                  Sauces, Pastes, & Gravies       8050
# 974   volume_oz                  Sauces, Pastes, & Gravies       8050
# 975   volume_oz                  Sauces, Pastes, & Gravies       8050
# 982   volume_oz                  Sauces, Pastes, & Gravies       8050
# 983   volume_oz                  Sauces, Pastes, & Gravies       8050
# 984   volume_oz                  Sauces, Pastes, & Gravies       8050
# 993   volume_oz                                      Salts       8045
# 994   volume_oz                                      Salts       8045
# 1115  volume_oz               Prepared Soft Drinks & Water       7588
# 1116  volume_oz               Prepared Soft Drinks & Water       7588
# 1121  volume_oz               Prepared Soft Drinks & Water       7588
# 1122  volume_oz               Prepared Soft Drinks & Water       7588
# 1123  volume_oz               Prepared Soft Drinks & Water       7588
# 1124  volume_oz               Prepared Soft Drinks & Water       7588
# 1125  volume_oz               Prepared Soft Drinks & Water       7588
# 1126  volume_oz               Prepared Soft Drinks & Water       7588
# 1127  volume_oz               Prepared Soft Drinks & Water       7588
# 1128  volume_oz               Prepared Soft Drinks & Water       7588
# 1129  volume_oz               Prepared Soft Drinks & Water       7588
# 1130  volume_oz               Prepared Soft Drinks & Water       7588
# 1155  volume_oz                            Prepared Juices       7586
# 1158  volume_oz                            Prepared Juices       7586
# 1164  volume_oz                            Prepared Juices       7586
# 1165  volume_oz                            Prepared Juices       7586
# 1166  volume_oz                            Prepared Juices       7586
# 1167  volume_oz                            Prepared Juices       7586
# 1169  volume_oz                            Prepared Juices       7586
# 1181  volume_oz                            Prepared Juices       7586
# 1182  volume_oz                            Prepared Juices       7586
# 1183  volume_oz                            Prepared Juices       7586
# 1184  volume_oz                            Prepared Juices       7586
# 1918  volume_oz                            Pasta & Noodles       8052
# 1919  volume_oz                            Pasta & Noodles       8052
# 2013  volume_oz            Pancake, Waffle, & Baking Mixes       8054
# 2014  volume_oz            Pancake, Waffle, & Baking Mixes       8054
# 2015  volume_oz            Pancake, Waffle, & Baking Mixes       8054
# 2016  volume_oz            Pancake, Waffle, & Baking Mixes       8054
# 2017  volume_oz            Pancake, Waffle, & Baking Mixes       8054
# 2018  volume_oz            Pancake, Waffle, & Baking Mixes       8054
# 2019  volume_oz            Pancake, Waffle, & Baking Mixes       8054
# 2020  volume_oz            Pancake, Waffle, & Baking Mixes       8054
# 2021  volume_oz            Pancake, Waffle, & Baking Mixes       8054
# 2022  volume_oz            Pancake, Waffle, & Baking Mixes       8054
# 2023  volume_oz            Pancake, Waffle, & Baking Mixes       8054
# 2081  volume_oz            Pain Relievers & Fever Reducers       7565
# 2433  volume_oz                     Oral Cleaning Products       7969
# 2434  volume_oz                     Oral Cleaning Products       7969
# 2435  volume_oz                     Oral Cleaning Products       7969
# 2436  volume_oz                     Oral Cleaning Products       7969
# 2437  volume_oz                     Oral Cleaning Products       7969
# 2438  volume_oz                     Oral Cleaning Products       7969
# 2439  volume_oz                     Oral Cleaning Products       7969
# 2440  volume_oz                     Oral Cleaning Products       7969
# 2441  volume_oz                     Oral Cleaning Products       7969
# 2442  volume_oz                     Oral Cleaning Products       7969
# 2443  volume_oz                     Oral Cleaning Products       7969
# 2444  volume_oz                     Oral Cleaning Products       7969
# 2445  volume_oz                     Oral Cleaning Products       7969
# 2446  volume_oz                     Oral Cleaning Products       7969
# 2447  volume_oz                     Oral Cleaning Products       7969
# 2448  volume_oz                     Oral Cleaning Products       7969
# 2449  volume_oz                     Oral Cleaning Products       7969
# 2450  volume_oz                     Oral Cleaning Products       7969
# 2451  volume_oz                     Oral Cleaning Products       7969
# 2452  volume_oz                     Oral Cleaning Products       7969
# 2453  volume_oz                     Oral Cleaning Products       7969
# 2454  volume_oz                     Oral Cleaning Products       7969
# 2455  volume_oz                     Oral Cleaning Products       7969
# 2456  volume_oz                     Oral Cleaning Products       7969
# 2457  volume_oz                     Oral Cleaning Products       7969
# 2458  volume_oz                     Oral Cleaning Products       7969
# 2459  volume_oz                     Oral Cleaning Products       7969
# 2460  volume_oz                     Oral Cleaning Products       7969
# 2461  volume_oz                     Oral Cleaning Products       7969
# 2462  volume_oz                     Oral Cleaning Products       7969
# 2551  volume_oz                 Olives, Pickles & Relishes       9377
# 2552  volume_oz                 Olives, Pickles & Relishes       9377
# 2554  volume_oz                 Olives, Pickles & Relishes       9377
# 2562  volume_oz                 Olives, Pickles & Relishes       9377
# 2564  volume_oz                              Oils (Edible)       7389
# 2574  volume_oz                              Oils (Edible)       7389
# 2575  volume_oz                              Oils (Edible)       7389
# 2906  volume_oz                  Nail Polishes & Adornment       8010
# 2907  volume_oz                  Nail Polishes & Adornment       8010
# 2908  volume_oz                  Nail Polishes & Adornment       8010
# 2909  volume_oz                  Nail Polishes & Adornment       8010
# 2910  volume_oz                  Nail Polishes & Adornment       8010
# 2911  volume_oz                  Nail Polishes & Adornment       8010
# 2912  volume_oz                  Nail Polishes & Adornment       8010
# 2913  volume_oz                  Nail Polishes & Adornment       8010
# 2927  volume_oz                  Nail Polishes & Adornment       8010
# 2928  volume_oz                  Nail Polishes & Adornment       8010
# 2929  volume_oz                  Nail Polishes & Adornment       8010
# 2930  volume_oz                  Nail Polishes & Adornment       8010
# 2931  volume_oz                  Nail Polishes & Adornment       8010
# 2932  volume_oz                  Nail Polishes & Adornment       8010
# 2937  volume_oz                  Nail Polishes & Adornment       8010
# 3105  volume_oz                  Nail Polishes & Adornment       8010
# 3106  volume_oz                  Nail Polishes & Adornment       8010
# 3107  volume_oz                  Nail Polishes & Adornment       8010
# 3108  volume_oz                  Nail Polishes & Adornment       8010
# 3109  volume_oz                  Nail Polishes & Adornment       8010
# 3110  volume_oz                  Nail Polishes & Adornment       8010
# 3111  volume_oz                  Nail Polishes & Adornment       8010
# 3112  volume_oz                  Nail Polishes & Adornment       8010
# 3113  volume_oz                  Nail Polishes & Adornment       8010
# 3114  volume_oz                  Nail Polishes & Adornment       8010
# 3115  volume_oz                  Nail Polishes & Adornment       8010
# 3116  volume_oz                  Nail Polishes & Adornment       8010
# 3117  volume_oz                  Nail Polishes & Adornment       8010
# 3118  volume_oz                  Nail Polishes & Adornment       8010
# 3119  volume_oz                  Nail Polishes & Adornment       8010
# 3120  volume_oz                  Nail Polishes & Adornment       8010
# 3121  volume_oz                  Nail Polishes & Adornment       8010
# 3122  volume_oz                  Nail Polishes & Adornment       8010
# 3123  volume_oz                  Nail Polishes & Adornment       8010
# 3131  volume_oz                  Nail Polishes & Adornment       8010
# 3132  volume_oz                  Nail Polishes & Adornment       8010
# 3133  volume_oz                  Nail Polishes & Adornment       8010
# 3144  volume_oz                  Nail Polishes & Adornment       8010
# 3145  volume_oz                  Nail Polishes & Adornment       8010
# 3146  volume_oz                  Nail Polishes & Adornment       8010
# 3147  volume_oz                  Nail Polishes & Adornment       8010
# 3148  volume_oz                  Nail Polishes & Adornment       8010
# 3149  volume_oz                  Nail Polishes & Adornment       8010
# 3150  volume_oz                  Nail Polishes & Adornment       8010
# 3151  volume_oz                  Nail Polishes & Adornment       8010
# 3152  volume_oz                  Nail Polishes & Adornment       8010
# 3153  volume_oz                  Nail Polishes & Adornment       8010
# 3154  volume_oz                  Nail Polishes & Adornment       8010
# 3191  volume_oz                  Nail Polishes & Adornment       8010
# 3192  volume_oz                  Nail Polishes & Adornment       8010
# 3193  volume_oz                  Nail Polishes & Adornment       8010
# 3194  volume_oz                  Nail Polishes & Adornment       8010
# 3239  volume_oz                  Nail Polishes & Adornment       8010
# 3240  volume_oz                  Nail Polishes & Adornment       8010
# 3241  volume_oz                  Nail Polishes & Adornment       8010
# 3242  volume_oz                  Nail Polishes & Adornment       8010
# 3243  volume_oz                  Nail Polishes & Adornment       8010
# 3319  volume_oz             Mouth Washes, Rinses, & Sprays       7970
# 3365  volume_oz                   Milk & Milk Alternatives       8041
# 3390  volume_oz                                    Mascara       7992
# 3391  volume_oz                                    Mascara       7992
# 3392  volume_oz                                    Mascara       7992
# 3393  volume_oz                                    Mascara       7992
# 3394  volume_oz                                    Mascara       7992
# 3551  volume_oz                     Lotions & Moisturizers       7381
# 3552  volume_oz                     Lotions & Moisturizers       7381
# 3553  volume_oz                     Lotions & Moisturizers       7381
# 3554  volume_oz                     Lotions & Moisturizers       7381
# 3555  volume_oz                     Lotions & Moisturizers       7381
# 3556  volume_oz                     Lotions & Moisturizers       7381
# 3557  volume_oz                     Lotions & Moisturizers       7381
# 3558  volume_oz                     Lotions & Moisturizers       7381
# 3559  volume_oz                     Lotions & Moisturizers       7381
# 3560  volume_oz                     Lotions & Moisturizers       7381
# 3561  volume_oz                     Lotions & Moisturizers       7381
# 3562  volume_oz                     Lotions & Moisturizers       7381
# 3563  volume_oz                     Lotions & Moisturizers       7381
# 3564  volume_oz                     Lotions & Moisturizers       7381
# 3565  volume_oz                     Lotions & Moisturizers       7381
# 3566  volume_oz                     Lotions & Moisturizers       7381
# 3629  volume_oz               Lipsticks, Glosses, & Stains       8004
# 3630  volume_oz               Lipsticks, Glosses, & Stains       8004
# 3631  volume_oz               Lipsticks, Glosses, & Stains       8004
# 3632  volume_oz               Lipsticks, Glosses, & Stains       8004
# 3633  volume_oz               Lipsticks, Glosses, & Stains       8004
# 3634  volume_oz               Lipsticks, Glosses, & Stains       8004
# 3635  volume_oz               Lipsticks, Glosses, & Stains       8004
# 3636  volume_oz               Lipsticks, Glosses, & Stains       8004
# 3651  volume_oz               Lipsticks, Glosses, & Stains       8004
# 3652  volume_oz               Lipsticks, Glosses, & Stains       8004
# 3653  volume_oz               Lipsticks, Glosses, & Stains       8004
# 3654  volume_oz               Lipsticks, Glosses, & Stains       8004
# 3729  volume_oz                Herbs, Spices, & Seasonings       8044
# 3748  volume_oz                Herbs, Spices, & Seasonings       8044
# 3749  volume_oz                Herbs, Spices, & Seasonings       8044
# 3750  volume_oz                Herbs, Spices, & Seasonings       8044
# 3751  volume_oz                Herbs, Spices, & Seasonings       8044
# 3752  volume_oz                Herbs, Spices, & Seasonings       8044
# 3753  volume_oz                Herbs, Spices, & Seasonings       8044
# 3755  volume_oz                Herbs, Spices, & Seasonings       8044
# 3756  volume_oz                Herbs, Spices, & Seasonings       8044
# 3757  volume_oz                Herbs, Spices, & Seasonings       8044
# 3758  volume_oz                Herbs, Spices, & Seasonings       8044
# 3759  volume_oz                Herbs, Spices, & Seasonings       8044
# 3760  volume_oz                Herbs, Spices, & Seasonings       8044
# 3761  volume_oz                Herbs, Spices, & Seasonings       8044
# 3762  volume_oz                Herbs, Spices, & Seasonings       8044
# 3763  volume_oz                Herbs, Spices, & Seasonings       8044
# 4060  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4061  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4062  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4063  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4064  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4065  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4066  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4067  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4077  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4078  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4079  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4080  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4081  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4082  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4083  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4084  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4085  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4087  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4088  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4089  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4090  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4091  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4113  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4114  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4115  volume_oz                Fruits, Vegetables, & Fungi       8026
# 4200  volume_oz          Foundations & Tinted Moisturizers       7998
# 4201  volume_oz          Foundations & Tinted Moisturizers       7998
# 4202  volume_oz          Foundations & Tinted Moisturizers       7998
# 4203  volume_oz          Foundations & Tinted Moisturizers       7998
# 4204  volume_oz          Foundations & Tinted Moisturizers       7998
# 4205  volume_oz          Foundations & Tinted Moisturizers       7998
# 4206  volume_oz          Foundations & Tinted Moisturizers       7998
# 4207  volume_oz          Foundations & Tinted Moisturizers       7998
# 4208  volume_oz          Foundations & Tinted Moisturizers       7998
# 4209  volume_oz          Foundations & Tinted Moisturizers       7998
# 4210  volume_oz          Foundations & Tinted Moisturizers       7998
# 4211  volume_oz          Foundations & Tinted Moisturizers       7998
# 4212  volume_oz          Foundations & Tinted Moisturizers       7998
# 4213  volume_oz          Foundations & Tinted Moisturizers       7998
# 4214  volume_oz          Foundations & Tinted Moisturizers       7998
# 4215  volume_oz          Foundations & Tinted Moisturizers       7998
# 4216  volume_oz          Foundations & Tinted Moisturizers       7998
# 4217  volume_oz          Foundations & Tinted Moisturizers       7998
# 4218  volume_oz          Foundations & Tinted Moisturizers       7998
# 4219  volume_oz          Foundations & Tinted Moisturizers       7998
# 4220  volume_oz          Foundations & Tinted Moisturizers       7998
# 4221  volume_oz          Foundations & Tinted Moisturizers       7998
# 4516  volume_oz       Facial Cleansers & Cosmetic Removers       7400
# 4517  volume_oz       Facial Cleansers & Cosmetic Removers       7400
# 4518  volume_oz       Facial Cleansers & Cosmetic Removers       7400
# 4519  volume_oz       Facial Cleansers & Cosmetic Removers       7400
# 4520  volume_oz       Facial Cleansers & Cosmetic Removers       7400
# 4577  volume_oz                           Face & Body Oils       8015
# 4578  volume_oz                           Face & Body Oils       8015
# 4579  volume_oz                           Face & Body Oils       8015
# 4580  volume_oz                           Face & Body Oils       8015
# 4592  volume_oz                           Eyebrow Products       7995
# 4602  volume_oz                           Eyebrow Products       7995
# 4634  volume_oz                              Dish Cleaners       7599
# 4635  volume_oz                              Dish Cleaners       7599
# 4636  volume_oz                              Dish Cleaners       7599
# 4637  volume_oz                              Dish Cleaners       7599
# 4638  volume_oz                              Dish Cleaners       7599
# 4639  volume_oz                              Dish Cleaners       7599
# 4640  volume_oz                              Dish Cleaners       7599
# 4642  volume_oz                              Dish Cleaners       7599
# 4662  volume_oz                              Dish Cleaners       7599
# 4663  volume_oz                              Dish Cleaners       7599
# 4664  volume_oz                              Dish Cleaners       7599
# 4665  volume_oz                              Dish Cleaners       7599
# 4676  volume_oz                              Dish Cleaners       7599
# 4677  volume_oz                              Dish Cleaners       7599
# 4683  volume_oz                              Dish Cleaners       7599
# 4684  volume_oz                              Dish Cleaners       7599
# 4690  volume_oz                              Dish Cleaners       7599
# 4758  volume_oz               Deodorants & Antiperspirants       7967
# 4759  volume_oz               Deodorants & Antiperspirants       7967
# 4760  volume_oz               Deodorants & Antiperspirants       7967
# 4761  volume_oz               Deodorants & Antiperspirants       7967
# 4762  volume_oz               Deodorants & Antiperspirants       7967
# 4763  volume_oz               Deodorants & Antiperspirants       7967
# 4764  volume_oz               Deodorants & Antiperspirants       7967
# 4765  volume_oz               Deodorants & Antiperspirants       7967
# 4766  volume_oz               Deodorants & Antiperspirants       7967
# 4767  volume_oz               Deodorants & Antiperspirants       7967
# 4923  volume_oz                         Cookies & Biscuits       8033
# 4924  volume_oz                         Cookies & Biscuits       8033
# 4925  volume_oz                         Cookies & Biscuits       8033
# 4926  volume_oz                         Cookies & Biscuits       8033
# 4927  volume_oz                         Cookies & Biscuits       8033
# 4928  volume_oz                         Cookies & Biscuits       8033
# 4929  volume_oz                         Cookies & Biscuits       8033
# 4930  volume_oz                         Cookies & Biscuits       8033
# 4931  volume_oz                         Cookies & Biscuits       8033
# 4932  volume_oz                         Cookies & Biscuits       8033
# 4933  volume_oz                         Cookies & Biscuits       8033
# 4934  volume_oz                         Cookies & Biscuits       8033
# 4935  volume_oz                         Cookies & Biscuits       8033
# 4936  volume_oz                         Cookies & Biscuits       8033
# 4937  volume_oz                         Cookies & Biscuits       8033
# 4938  volume_oz                         Cookies & Biscuits       8033
# 4939  volume_oz                         Cookies & Biscuits       8033
# 5138  volume_oz              Concealers & Color Correctors       8002
# 5139  volume_oz              Concealers & Color Correctors       8002
# 5140  volume_oz              Concealers & Color Correctors       8002
# 5141  volume_oz              Concealers & Color Correctors       8002
# 5142  volume_oz              Concealers & Color Correctors       8002
# 5143  volume_oz              Concealers & Color Correctors       8002
# 5144  volume_oz              Concealers & Color Correctors       8002
# 5145  volume_oz              Concealers & Color Correctors       8002
# 5146  volume_oz              Concealers & Color Correctors       8002
# 5147  volume_oz              Concealers & Color Correctors       8002
# 5148  volume_oz              Concealers & Color Correctors       8002
# 5149  volume_oz              Concealers & Color Correctors       8002
# 5704  volume_oz                           Chips & Crackers       8029
# 5705  volume_oz                           Chips & Crackers       8029
# 5706  volume_oz                           Chips & Crackers       8029
# 5707  volume_oz                           Chips & Crackers       8029
# 5708  volume_oz                           Chips & Crackers       8029
# 5709  volume_oz                           Chips & Crackers       8029
# 5710  volume_oz                           Chips & Crackers       8029
# 5711  volume_oz                           Chips & Crackers       8029
# 5712  volume_oz                           Chips & Crackers       8029
# 5713  volume_oz                           Chips & Crackers       8029
# 5714  volume_oz                           Chips & Crackers       8029
# 5715  volume_oz                           Chips & Crackers       8029
# 5716  volume_oz                           Chips & Crackers       8029
# 5717  volume_oz                           Chips & Crackers       8029
# 5718  volume_oz                           Chips & Crackers       8029
# 5719  volume_oz                           Chips & Crackers       8029
# 5720  volume_oz                           Chips & Crackers       8029
# 5721  volume_oz                           Chips & Crackers       8029
# 5722  volume_oz                           Chips & Crackers       8029
# 5723  volume_oz                           Chips & Crackers       8029
# 5724  volume_oz                           Chips & Crackers       8029
# 5725  volume_oz                           Chips & Crackers       8029
# 5726  volume_oz                           Chips & Crackers       8029
# 5727  volume_oz                           Chips & Crackers       8029
# 5764  volume_oz                    Cereals & Pseudocereals       8051
# 5765  volume_oz                    Cereals & Pseudocereals       8051
# 5766  volume_oz                    Cereals & Pseudocereals       8051
# 5767  volume_oz                    Cereals & Pseudocereals       8051
# 5768  volume_oz                    Cereals & Pseudocereals       8051
# 5769  volume_oz                    Cereals & Pseudocereals       8051
# 5770  volume_oz                    Cereals & Pseudocereals       8051
# 5771  volume_oz                    Cereals & Pseudocereals       8051
# 5772  volume_oz                    Cereals & Pseudocereals       8051
# 6028  volume_oz            Bronzer, Contour, & Highlighter       7999
# 6029  volume_oz            Bronzer, Contour, & Highlighter       7999
# 6030  volume_oz            Bronzer, Contour, & Highlighter       7999
# 6324  volume_oz                          Adhesives & Glues       8615
# 6325  volume_oz                          Adhesives & Glues       8615
# 6326  volume_oz                          Adhesives & Glues       8615
# 6327  volume_oz                          Adhesives & Glues       8615
# 6328  volume_oz                          Adhesives & Glues       8615
# 6329  volume_oz                          Adhesives & Glues       8615
# 6330  volume_oz                          Adhesives & Glues       8615
# 6338  volume_oz                          Adhesives & Glues       8615
#
#                     value customer_name external_id  \
# 168            0 - 1.9 oz  familydollar     1297553
# 169            0 - 1.9 oz  familydollar     1207342
# 170            0 - 1.9 oz  familydollar     1204703
# 171            0 - 1.9 oz  familydollar     1202473
# 172            0 - 1.9 oz  familydollar     1202296
# 173            0 - 1.9 oz  familydollar     1202233
# 356            2 - 3.9 oz  familydollar     1202286
# 357            2 - 3.9 oz  familydollar      901507
# 358            2 - 3.9 oz  familydollar      999984
# 359          32 - 39.9 oz  familydollar      900877
# 360            4 - 7.9 oz  familydollar      999482
# 361            4 - 7.9 oz  familydollar      999983
# 362           8 - 15.9 oz  familydollar      998780
# 410          64 - 71.9 oz  familydollar     1219393
# 411          32 - 39.9 oz  familydollar     1298320
# 412          32 - 39.9 oz  familydollar     1219391
# 418          16 - 23.9 oz  familydollar     1203973
# 419          16 - 23.9 oz  familydollar     1203969
# 464           8 - 15.9 oz  familydollar     1202190
# 465          32 - 39.9 oz  familydollar     1202419
# 466          24 - 31.9 oz  familydollar     1209086
# 467          24 - 31.9 oz  familydollar     1202063
# 469            2 - 3.9 oz  familydollar     1205015
# 470            0 - 1.9 oz  familydollar     1202619
# 790           8 - 15.9 oz  familydollar     1220168
# 794           8 - 15.9 oz  familydollar     1218629
# 798           8 - 15.9 oz  familydollar     1218627
# 800           8 - 15.9 oz  familydollar     1219428
# 809           8 - 15.9 oz  familydollar     1218153
# 810          24 - 31.9 oz  familydollar     1218866
# 811          24 - 31.9 oz  familydollar     1218869
# 812          32 - 39.9 oz  familydollar     1200364
# 820           8 - 15.9 oz  familydollar     1217162
# 831          16 - 23.9 oz  familydollar     1217887
# 832          16 - 23.9 oz  familydollar     1217354
# 833          16 - 23.9 oz  familydollar     1217296
# 834          16 - 23.9 oz  familydollar     1217146
# 839           8 - 15.9 oz  familydollar     1217273
# 840           8 - 15.9 oz  familydollar     1218140
# 841           8 - 15.9 oz  familydollar     1218141
# 842          16 - 23.9 oz  familydollar     1217888
# 917          16 - 23.9 oz  familydollar     1218485
# 919          24 - 31.9 oz  familydollar     1296509
# 920            2 - 3.9 oz  familydollar     1220967
# 926          16 - 23.9 oz  familydollar     1297374
# 929          16 - 23.9 oz  familydollar     1200558
# 930            4 - 7.9 oz  familydollar      998302
# 965            0 - 1.9 oz  familydollar     1219274
# 968           8 - 15.9 oz  familydollar     1205034
# 969           8 - 15.9 oz  familydollar     1219287
# 970           8 - 15.9 oz  familydollar     1218626
# 974           8 - 15.9 oz  familydollar     1218482
# 975           8 - 15.9 oz  familydollar     1206270
# 982           8 - 15.9 oz  familydollar     1200699
# 983            4 - 7.9 oz  familydollar     1205395
# 984          24 - 31.9 oz  familydollar     1217452
# 993            4 - 7.9 oz  familydollar     1204929
# 994          16 - 23.9 oz  familydollar     1200460
# 1115           0 - 1.9 oz  familydollar     1200833
# 1116           0 - 1.9 oz  familydollar     1202602
# 1121           0 - 1.9 oz  familydollar     1205380
# 1122           0 - 1.9 oz  familydollar     1207350
# 1123         16 - 23.9 oz  familydollar     1202043
# 1124         16 - 23.9 oz  familydollar     1202278
# 1125         24 - 31.9 oz  familydollar     2786022
# 1126         48 - 55.9 oz  familydollar     1202378
# 1127     80 oz or Greater  familydollar     1208781
# 1128          8 - 15.9 oz  familydollar     1202441
# 1129          8 - 15.9 oz  familydollar     2785736
# 1130          8 - 15.9 oz  familydollar     2786125
# 1155         32 - 39.9 oz  familydollar     1209185
# 1158         40 - 47.9 oz  familydollar     1202172
# 1164         40 - 47.9 oz  familydollar     1202336
# 1165         64 - 71.9 oz  familydollar     1202060
# 1166         64 - 71.9 oz  familydollar     1202061
# 1167         64 - 71.9 oz  familydollar     1202071
# 1169         32 - 39.9 oz  familydollar     1202341
# 1181         64 - 71.9 oz  familydollar     1299065
# 1182         64 - 71.9 oz  familydollar     1299061
# 1183         64 - 71.9 oz  familydollar     1204998
# 1184         64 - 71.9 oz  familydollar     1202074
# 1918          8 - 15.9 oz  familydollar     1200399
# 1919          8 - 15.9 oz  familydollar     1217020
# 2013          8 - 15.9 oz  familydollar     1218883
# 2014          8 - 15.9 oz  familydollar     1207380
# 2015           4 - 7.9 oz  familydollar     1219341
# 2016           4 - 7.9 oz  familydollar     1218882
# 2017           4 - 7.9 oz  familydollar     1218189
# 2018           4 - 7.9 oz  familydollar     1218188
# 2019         16 - 23.9 oz  familydollar     1220225
# 2020         16 - 23.9 oz  familydollar     1220181
# 2021         16 - 23.9 oz  familydollar     1219398
# 2022         16 - 23.9 oz  familydollar     1218542
# 2023         16 - 23.9 oz  familydollar     1218184
# 2081          0 - 0.25 oz  familydollar      912968
# 2433          0 - 0.25 oz  familydollar      901750
# 2434        0.26 - 0.5 oz  familydollar      903225
# 2435         2.1 - 2.5 oz  familydollar      905703
# 2436         2.1 - 2.5 oz  familydollar      907151
# 2437         2.1 - 2.5 oz  familydollar      907170
# 2438         2.1 - 2.5 oz  familydollar      907874
# 2439         2.6 - 3.0 oz  familydollar      907000
# 2440         2.6 - 3.0 oz  familydollar      907781
# 2441         2.6 - 3.0 oz  familydollar      999091
# 2442  Greater than 3.0 oz  familydollar      900932
# 2443  Greater than 3.0 oz  familydollar      901782
# 2444  Greater than 3.0 oz  familydollar      901784
# 2445  Greater than 3.0 oz  familydollar      902134
# 2446  Greater than 3.0 oz  familydollar      902143
# 2447  Greater than 3.0 oz  familydollar      903152
# 2448  Greater than 3.0 oz  familydollar      903245
# 2449  Greater than 3.0 oz  familydollar      905028
# 2450  Greater than 3.0 oz  familydollar      905517
# 2451  Greater than 3.0 oz  familydollar      906406
# 2452  Greater than 3.0 oz  familydollar      907121
# 2453  Greater than 3.0 oz  familydollar      907136
# 2454  Greater than 3.0 oz  familydollar      907220
# 2455  Greater than 3.0 oz  familydollar      907329
# 2456  Greater than 3.0 oz  familydollar      907634
# 2457  Greater than 3.0 oz  familydollar      907839
# 2458  Greater than 3.0 oz  familydollar      999099
# 2459  Greater than 3.0 oz  familydollar      999318
# 2460  Greater than 3.0 oz  familydollar      999383
# 2461  Greater than 3.0 oz  familydollar      999386
# 2462  Greater than 3.0 oz  familydollar      999498
# 2551         24 - 31.9 oz  familydollar     1204479
# 2552         16 - 23.9 oz  familydollar     1218266
# 2554          8 - 15.9 oz  familydollar     1299610
# 2562          8 - 15.9 oz  familydollar     1218268
# 2564          8 - 15.9 oz  familydollar     1207220
# 2574         48 - 55.9 oz  familydollar     1217547
# 2575         16 - 23.9 oz  familydollar     1219381
# 2906        0.26 - 0.5 oz  familydollar     2002612
# 2907        0.26 - 0.5 oz  familydollar     2002761
# 2908        0.26 - 0.5 oz  familydollar     2003169
# 2909        0.26 - 0.5 oz  familydollar     2003171
# 2910        0.26 - 0.5 oz  familydollar     2003173
# 2911        0.26 - 0.5 oz  familydollar     2003175
# 2912        0.26 - 0.5 oz  familydollar     2003176
# 2913        0.26 - 0.5 oz  familydollar     2003177
# 2927        0.26 - 0.5 oz  familydollar     2003277
# 2928        0.26 - 0.5 oz  familydollar     2003285
# 2929        0.26 - 0.5 oz  familydollar     2003286
# 2930        0.26 - 0.5 oz  familydollar     2003287
# 2931        0.26 - 0.5 oz  familydollar     2003289
# 2932        0.26 - 0.5 oz  familydollar     2003290
# 2937        0.26 - 0.5 oz  familydollar     2002060
# 3105        0.26 - 0.5 oz  familydollar     2004129
# 3106        0.26 - 0.5 oz  familydollar     2004205
# 3107        0.26 - 0.5 oz  familydollar     2004215
# 3108        0.26 - 0.5 oz  familydollar     2004227
# 3109        0.26 - 0.5 oz  familydollar     2004242
# 3110        0.26 - 0.5 oz  familydollar     2004243
# 3111        0.26 - 0.5 oz  familydollar     2004382
# 3112        0.26 - 0.5 oz  familydollar     2004383
# 3113        0.26 - 0.5 oz  familydollar     2004384
# 3114        0.26 - 0.5 oz  familydollar     2005278
# 3115        0.26 - 0.5 oz  familydollar     2005354
# 3116        0.26 - 0.5 oz  familydollar     2006336
# 3117        0.26 - 0.5 oz  familydollar     2007136
# 3118        0.26 - 0.5 oz  familydollar     2007137
# 3119        0.26 - 0.5 oz  familydollar     2007138
# 3120        0.26 - 0.5 oz  familydollar     2007139
# 3121        0.26 - 0.5 oz  familydollar     2007140
# 3122        0.26 - 0.5 oz  familydollar     2007141
# 3123        0.26 - 0.5 oz  familydollar     2007142
# 3131        0.26 - 0.5 oz  familydollar     2007647
# 3132        0.26 - 0.5 oz  familydollar     2007652
# 3133        0.26 - 0.5 oz  familydollar     2044408
# 3144        0.26 - 0.5 oz  familydollar     2098684
# 3145        0.26 - 0.5 oz  familydollar     2098686
# 3146        0.26 - 0.5 oz  familydollar     2098687
# 3147        0.26 - 0.5 oz  familydollar     2098805
# 3148        0.26 - 0.5 oz  familydollar     2098806
# 3149        0.26 - 0.5 oz  familydollar     2098808
# 3150        0.26 - 0.5 oz  familydollar     2098812
# 3151        0.26 - 0.5 oz  familydollar     2099562
# 3152        0.26 - 0.5 oz  familydollar     2099563
# 3153        0.26 - 0.5 oz  familydollar     2099565
# 3154        0.26 - 0.5 oz  familydollar     2099566
# 3191          0 - 0.25 oz  familydollar     2006546
# 3192          0 - 0.25 oz  familydollar     2042159
# 3193          0 - 0.25 oz  familydollar     2042233
# 3194          0 - 0.25 oz  familydollar     2042234
# 3239          0 - 0.25 oz  familydollar     2098960
# 3240        0.26 - 0.5 oz  familydollar     2002077
# 3241        0.26 - 0.5 oz  familydollar     2002079
# 3242        0.26 - 0.5 oz  familydollar     2002082
# 3243        0.26 - 0.5 oz  familydollar     2002083
# 3319           6 - 8.9 oz  familydollar      902364
# 3365          8 - 15.9 oz  familydollar     1202417
# 3390        0.26 - 0.5 oz  familydollar     2099591
# 3391        0.26 - 0.5 oz  familydollar     2007386
# 3392        0.26 - 0.5 oz  familydollar     2005002
# 3393        0.26 - 0.5 oz  familydollar     2004905
# 3394        0.26 - 0.5 oz  familydollar     2001576
# 3551           0 - 2.9 oz  familydollar     2006941
# 3552           0 - 2.9 oz  familydollar     2032110
# 3553           0 - 2.9 oz  familydollar     2033621
# 3554           0 - 2.9 oz  familydollar     2097484
# 3555           0 - 7.9 oz  familydollar     2095815
# 3556         12 - 14.9 oz  familydollar     2096494
# 3557         12 - 14.9 oz  familydollar      902792
# 3558         12 - 14.9 oz  familydollar      999680
# 3559         15 - 23.9 oz  familydollar      999858
# 3560           3 - 5.9 oz  familydollar     2008086
# 3561           3 - 5.9 oz  familydollar     2028375
# 3562           3 - 5.9 oz  familydollar     2032180
# 3563           3 - 5.9 oz  familydollar     2095832
# 3564           6 - 8.9 oz  familydollar      900016
# 3565          8 - 15.9 oz  familydollar     2033120
# 3566          8 - 15.9 oz  familydollar     2033140
# 3629          0 - 0.25 oz  familydollar     2003190
# 3630          0 - 0.25 oz  familydollar     2003532
# 3631          0 - 0.25 oz  familydollar     2003560
# 3632          0 - 0.25 oz  familydollar     2005032
# 3633          0 - 0.25 oz  familydollar     2005036
# 3634          0 - 0.25 oz  familydollar     2005038
# 3635          0 - 0.25 oz  familydollar     2005082
# 3636          0 - 0.25 oz  familydollar     2098794
# 3651          0 - 0.25 oz  familydollar     2098795
# 3652          0 - 0.25 oz  familydollar     2098796
# 3653          0 - 0.25 oz  familydollar     2098957
# 3654        0.26 - 0.5 oz  familydollar     2041697
# 3729           2 - 3.9 oz  familydollar     1204949
# 3748          8 - 15.9 oz  familydollar     1205911
# 3749           4 - 7.9 oz  familydollar     1205253
# 3750           4 - 7.9 oz  familydollar     1204979
# 3751           4 - 7.9 oz  familydollar     1204927
# 3752           2 - 3.9 oz  familydollar     1221472
# 3753           2 - 3.9 oz  familydollar     1204950
# 3755           2 - 3.9 oz  familydollar     1204932
# 3756           2 - 3.9 oz  familydollar     1204928
# 3757           2 - 3.9 oz  familydollar     1204906
# 3758           2 - 3.9 oz  familydollar     1202767
# 3759         16 - 23.9 oz  familydollar     1298567
# 3760           0 - 1.9 oz  familydollar     1204933
# 3761           0 - 1.9 oz  familydollar     1204924
# 3762           0 - 1.9 oz  familydollar     1204923
# 3763           0 - 1.9 oz  familydollar     1204921
# 4060         24 - 31.9 oz  familydollar     1218517
# 4061           4 - 7.9 oz  familydollar     1217314
# 4062          8 - 15.9 oz  familydollar     1205481
# 4063          8 - 15.9 oz  familydollar     1205630
# 4064          8 - 15.9 oz  familydollar     1209204
# 4065          8 - 15.9 oz  familydollar     1217161
# 4066          8 - 15.9 oz  familydollar     1217368
# 4067          8 - 15.9 oz  familydollar     1217369
# 4077          8 - 15.9 oz  familydollar     1219346
# 4078          8 - 15.9 oz  familydollar     1220279
# 4079          8 - 15.9 oz  familydollar     1221483
# 4080          8 - 15.9 oz  familydollar     1221485
# 4081          8 - 15.9 oz  familydollar     1218708
# 4082          8 - 15.9 oz  familydollar     1218709
# 4083          8 - 15.9 oz  familydollar     1218710
# 4084          8 - 15.9 oz  familydollar     1218711
# 4085          8 - 15.9 oz  familydollar     1218712
# 4087          8 - 15.9 oz  familydollar     1218713
# 4088          8 - 15.9 oz  familydollar     1218855
# 4089         24 - 31.9 oz  familydollar     1206261
# 4090         24 - 31.9 oz  familydollar     1207009
# 4091         24 - 31.9 oz  familydollar     1218212
# 4113         16 - 23.9 oz  familydollar     1208062
# 4114         16 - 23.9 oz  familydollar     1208063
# 4115         16 - 23.9 oz  familydollar     1217912
# 4200         1.1 - 1.5 oz  familydollar     2097850
# 4201         1.1 - 1.5 oz  familydollar     2007467
# 4202        0.76 - 1.0 oz  familydollar     2099816
# 4203        0.76 - 1.0 oz  familydollar     2099815
# 4204        0.76 - 1.0 oz  familydollar     2099813
# 4205        0.76 - 1.0 oz  familydollar     2099812
# 4206        0.76 - 1.0 oz  familydollar     2099808
# 4207        0.76 - 1.0 oz  familydollar     2099807
# 4208        0.76 - 1.0 oz  familydollar     2099659
# 4209        0.76 - 1.0 oz  familydollar     2099657
# 4210        0.76 - 1.0 oz  familydollar     2098841
# 4211        0.76 - 1.0 oz  familydollar     2098840
# 4212        0.76 - 1.0 oz  familydollar     2098835
# 4213        0.76 - 1.0 oz  familydollar     2098834
# 4214        0.76 - 1.0 oz  familydollar     2098831
# 4215        0.76 - 1.0 oz  familydollar     2041307
# 4216        0.76 - 1.0 oz  familydollar     2041304
# 4217        0.76 - 1.0 oz  familydollar     2041300
# 4218        0.26 - 0.5 oz  familydollar     2099756
# 4219        0.26 - 0.5 oz  familydollar     2099755
# 4220        0.26 - 0.5 oz  familydollar     2099653
# 4221        0.26 - 0.5 oz  familydollar     2041532
# 4516           3 - 5.9 oz  familydollar     2004591
# 4517           3 - 5.9 oz  familydollar     2024854
# 4518           3 - 5.9 oz  familydollar     2032166
# 4519           3 - 5.9 oz  familydollar     2096456
# 4520           3 - 5.9 oz  familydollar     2097513
# 4577          8 - 15.9 oz  familydollar      998797
# 4578          8 - 15.9 oz  familydollar      911180
# 4579           6 - 8.9 oz  familydollar      900912
# 4580         12 - 14.9 oz  familydollar      901663
# 4592          0 - 0.25 oz  familydollar     2099596
# 4602          0 - 0.25 oz  familydollar     2099595
# 4634          8 - 15.9 oz  familydollar     1401420
# 4635          8 - 15.9 oz  familydollar     1414029
# 4636          8 - 15.9 oz  familydollar     1414031
# 4637          8 - 15.9 oz  familydollar     1414277
# 4638         24 - 31.9 oz  familydollar     1414000
# 4639         24 - 31.9 oz  familydollar     1414027
# 4640         24 - 31.9 oz  familydollar     1414262
# 4642         24 - 31.9 oz  familydollar     1414274
# 4662         16 - 23.9 oz  familydollar     1401286
# 4663         16 - 23.9 oz  familydollar     1414273
# 4664         16 - 23.9 oz  familydollar     1498999
# 4665         24 - 31.9 oz  familydollar     1400899
# 4676         32 - 39.9 oz  familydollar     1414276
# 4677         40 - 47.9 oz  familydollar     1499378
# 4683           4 - 7.9 oz  familydollar     1499385
# 4684           4 - 7.9 oz  familydollar     1499417
# 4690     80 oz or Greater  familydollar     1400916
# 4758         1.1 - 1.5 oz  familydollar     2028544
# 4759         1.6 - 2.0 oz  familydollar     2028261
# 4760         2.6 - 3.0 oz  familydollar     2028225
# 4761         2.6 - 3.0 oz  familydollar     2028468
# 4762         2.6 - 3.0 oz  familydollar     2044182
# 4763         2.6 - 3.0 oz  familydollar     2099968
# 4764  Greater than 3.0 oz  familydollar     2006098
# 4765  Greater than 3.0 oz  familydollar     2028379
# 4766  Greater than 3.0 oz  familydollar     2028613
# 4767  Greater than 3.0 oz  familydollar     2098924
# 4923         16 - 23.9 oz  familydollar     1200381
# 4924         16 - 23.9 oz  familydollar     1207374
# 4925         16 - 23.9 oz  familydollar     1208119
# 4926           2 - 3.9 oz  familydollar     1204943
# 4927           2 - 3.9 oz  familydollar     1204944
# 4928           2 - 3.9 oz  familydollar     1204945
# 4929           2 - 3.9 oz  familydollar     1217359
# 4930         24 - 31.9 oz  familydollar     1298001
# 4931           4 - 7.9 oz  familydollar     1219523
# 4932           4 - 7.9 oz  familydollar     1220034
# 4933           4 - 7.9 oz  familydollar     1297503
# 4934          8 - 15.9 oz  familydollar     1200876
# 4935          8 - 15.9 oz  familydollar     1201788
# 4936          8 - 15.9 oz  familydollar     1219210
# 4937          8 - 15.9 oz  familydollar     1219499
# 4938          8 - 15.9 oz  familydollar     1220119
# 4939          8 - 15.9 oz  familydollar     1295011
# ...
# 2906      [44 oz]              []                 [44-oz]
# 2907      [44 oz]              []                 [44-oz]
# 2908      [44 oz]              []                 [44-oz]
# 2909      [44 oz]              []                 [44-oz]
# 2910      [44 oz]              []                 [44-oz]
# 2911      [44 oz]              []                 [44-oz]
# 2912      [44 oz]              []                 [44-oz]
# 2913      [44 oz]              []                 [44-oz]
# 2927      [44 oz]              []                 [44-oz]
# 2928      [44 oz]              []                 [44-oz]
# 2929      [44 oz]              []          [44 oz, 44-oz]
# 2930      [44 oz]              []           [44-oz, 1 oz]
# 2931      [44 oz]              []           [0 oz, 44-oz]
# 2932      [44 oz]              []           [0 oz, 44-oz]
# 2937      [44-oz]              []          [44 oz, 44-oz]
# 3105      [44-oz]              []                 [44-oz]
# 3106      [44-oz]              []                 [44-oz]
# 3107      [44 oz]              []          [44 oz, 44-oz]
# 3108      [44 oz]              []                 [44-oz]
# 3109      [44 oz]              []           [44 oz, 0 oz]
# 3110      [44 oz]              []                      []
# 3111      [44 oz]              []                 [44-oz]
# 3112      [44 oz]              []                 [44-oz]
# 3113      [44 oz]              []           [0 oz, 44-oz]
# 3114      [44 oz]              []                 [44-oz]
# 3115      [44 oz]              []                      []
# 3116      [44 oz]              []                      []
# 3117      [44 oz]              []          [44 oz, 44-oz]
# 3118      [44 oz]              []           [0 oz, 44-oz]
# 3119      [44 oz]              []                      []
# 3120      [44 oz]              []                      []
# 3121      [44 oz]              []                      []
# 3122      [44 oz]              []                      []
# 3123      [44 oz]              []                      []
# 3131           []              []                 [47 oz]
# 3132           []              []                 [47 oz]
# 3133      [44 oz]              []                      []
# 3144      [44 oz]              []                      []
# 3145      [44 oz]              []                      []
# 3146      [44 oz]              []                      []
# 3147      [44 oz]              []                      []
# 3148      [44 oz]              []                      []
# 3149      [44 oz]              []                      []
# 3150      [44 oz]              []                      []
# 3151      [44 oz]              []                      []
# 3152      [44 oz]              []                      []
# 3153      [44 oz]              []                      []
# 3154      [44 oz]              []                      []
# 3191      [18 oz]              []                      []
# 3192           []              []                      []
# 3193     [0.1 oz]              []          [0 oz, 0.1-oz]
# 3194           []              []                      []
# 3239      [07 oz]              []          [07-oz, 07 oz]
# 3240      [44 oz]              []                 [44-oz]
# 3241      [44 oz]              []                 [44-oz]
# 3242      [44 oz]              []                 [44-oz]
# 3243      [44 oz]              []                 [44-oz]
# 3319     [8.5 oz]              []                      []
# 3365           []              []                      []
# 3390      [33 oz]              []                      []
# 3391      [27 oz]              []                      []
# 3392     [0.3 oz]              []                      []
# 3393      [33 oz]              []                      []
# 3394      [43 oz]              []                      []
# 3551       [1 oz]              []            [0 oz, 1-oz]
# 3552       [1 oz]              []                  [1 oz]
# 3553     [1.1-oz]              []                [1.1-oz]
# 3554       [1-oz]              []          [1-oz, 1.2 oz]
# 3555        [3oz]              []            [25 oz, 3oz]
# 3556    [13.5-oz]              []         [13.5-oz, 0 oz]
# 3557    [13.6 oz]              []                      []
# 3558           []              []                      []
# 3559    [16.9 oz]              []                      []
# 3560     [4.5-oz]              []        [5.8 oz, 4.5-oz]
# 3561     [4.3-oz]              []        [4.3-oz, 6.4 oz]
# 3562       [4-oz]              []           [4-oz, 35 oz]
# 3563     [5.5-oz]              []        [6.8 oz, 5.5-oz]
# 3564       [8 oz]              []                  [8 oz]
# 3565      [10 oz]              []                 [10 oz]
# 3566    [12.5 oz]              []               [12.5 oz]
# 3629      [14 oz]              []                      []
# 3630      [12 oz]              []                 [12 oz]
# 3631      [14 oz]              []                 [14-oz]
# 3632      [13 oz]              []          [13-oz, 13 oz]
# 3633      [13 oz]              []          [13-oz, 13 oz]
# 3634      [13 oz]              []          [13-oz, 13 oz]
# 3635      [13 oz]              []          [13-oz, 13 oz]
# 3636      [14 oz]              []          [12 oz, 14-oz]
# 3651      [14 oz]              []                      []
# 3652      [14 oz]              []          [12 oz, 14-oz]
# 3653      [12 oz]              []                      []
# 3654           []              []                      []
# 3729       [3 oz]              []                      []
# 3748       [8-oz]          [8-oz]            [8-oz, 8 oz]
# 3749     [5.4 oz]              []                      []
# 3750       [6 oz]              []                      []
# 3751      [65 oz]              []                      []
# 3752     [2.5 oz]              []                [2.5 oz]
# 3753       [2 oz]              []                      []
# 3755      [17 oz]              []                      []
# 3756      [25 oz]              []                      []
# 3757     [2.5 oz]              []                      []
# 3758       [3 oz]              []                      []
# 3759      [17-oz]         [17-oz]          [17 oz, 17-oz]
# 3760      [49 oz]              []                      []
# 3761      [23 oz]              []                      []
# 3762      [76 oz]              []                      []
# 3763      [58 oz]              []                      []
# 4060      [29 oz]              []                 [29 oz]
# 4061       [4 oz]              []                  [4 oz]
# 4062    [14.5 oz]              []               [14.5 oz]
# 4063      [12 oz]              []                 [12 oz]
# 4064    [14.5 oz]              []               [14.5 oz]
# 4065      [25 oz]              []                 [25 oz]
# 4066    [14.5 oz]              []                      []
# 4067      [25 oz]              []                 [25 oz]
# 4077      [15 oz]              []                 [15 oz]
# 4078    [14.5 oz]              []               [14.5 oz]
# 4079      [15 oz]              []                 [15 oz]
# 4080    [14.5 oz]              []               [14.5 oz]
# 4081      [25 oz]              []                 [25 oz]
# 4082      [75 oz]              []                 [75 oz]
# 4083    [14.5 oz]              []                      []
# 4084    [14.5 oz]              []                      []
# 4085      [15 oz]              []                 [15 oz]
# 4087      [15 oz]              []                 [15 oz]
# 4088      [15 oz]              []                 [15 oz]
# 4089      [27 oz]              []                      []
# 4090      [27 oz]              []                 [27 oz]
# 4091      [29 oz]              []                      []
# 4113      [20 oz]              []                      []
# 4114      [20 oz]              []                      []
# 4115      [20 oz]              []                      []
# 4200      [11-oz]              []          [11-oz, 11 oz]
# 4201      [35-oz]              []           [0 oz, 35-oz]
# 4202       [1 oz]              []                      []
# 4203       [1 oz]              []                      []
# 4204       [1 oz]              []                      []
# 4205       [1 oz]              []                      []
# 4206       [1 oz]              []                      []
# 4207       [1 oz]              []                      []
# 4208       [1 oz]          [1-oz]            [1-oz, 1 oz]
# 4209       [1 oz]              []            [0 oz, 1-oz]
# 4210       [1 oz]              []                      []
# 4211       [1 oz]              []                      []
# 4212       [1 oz]              []                      []
# 4213       [1 oz]              []                      []
# 4214       [1 oz]              []                      []
# 4215       [1 oz]              []                      []
# 4216       [1 oz]              []                      []
# 4217       [1 oz]              []                  [1 oz]
# 4218     [0.3 oz]              []                [0.3 oz]
# 4219           []              []                 [29 oz]
# 4220      [26 oz]              []          [26-oz, 26 oz]
# 4221      [32 oz]              []          [32-oz, 32 oz]
# 4516     [3.5 oz]              []                [3.5 oz]
# 4517     [3.5 oz]              []                [3.5 oz]
# 4518       [4-oz]              []           [4-oz, 34 oz]
# 4519           []              []                [6.3 oz]
# 4520       [4-oz]              []           [4-oz, 35 oz]
# 4577           []              []                      []
# 4578      [14 oz]              []                      []
# 4579     [6.5 oz]              []                      []
# 4580      [14 oz]              []                 [14 oz]
# 4592      [11 oz]              []                      []
# 4602      [11 oz]              []           [11-oz, 1 oz]
# 4634           []              []                [8.8 oz]
# 4635      [14 oz]              []               [12.6 oz]
# 4636      [14 oz]              []                      []
# 4637      [10 oz]              []                      []
# 4638      [28 oz]              []                      []
# 4639      [28 oz]              []                      []
# 4640      [28 oz]              []                      []
# 4642      [24 oz]              []                      []
# 4662           []              []                      []
# 4663    [21.6 oz]              []                      []
# 4664           []              []                      []
# 4665           []              []                      []
# 4676    [32.5 oz]              []      [32.5 oz, 32.5-oz]
# 4677           []              []                      []
# 4683           []              []                      []
# 4684           []              []                      []
# 4690           []              []                 [84 oz]
# 4758     [1.4 oz]              []          [0 oz, 1.4-oz]
# 4759     [1.6 oz]              []          [0 oz, 1.6-oz]
# 4760       [3 oz]              []                  [3 oz]
# 4761     [2.6 oz]              []                [2.6-oz]
# 4762           []              []                  [3 oz]
# 4763           []              []                [2.6 oz]
# 4764     [3.8 oz]              []          [3.8-oz, 0 oz]
# 4765           []        [2.6-oz]                  [0 oz]
# 4766      [10 oz]              []           [10-oz, 0 oz]
# 4767           []              []                  [0 oz]
# 4923    [19.1 oz]              []               [19.1 oz]
# 4924       [20oz]              []                  [0 oz]
# 4925      [16 oz]              []                 [16 oz]
# 4926     [3.5 oz]              []                [3.5 oz]
# 4927       [3 oz]          [3-oz]                  [3 oz]
# 4928       [3 oz]              []                  [3 oz]
# 4929     [2.2 oz]              []                      []
# 4930      [25 oz]              []                      []
# 4931           []              []                      []
# 4932     [7.1 oz]              []                [7.1 oz]
# 4933     [5.3 oz]              []                      []
# 4934      [13 oz]              []                      []
# 4935      [13 oz]              []                 [13 oz]
# 4936       [8 oz]              []                  [8 oz]
# 4937       [8 oz]              []                  [8 oz]
# 4938      [11 oz]              []                 [11 oz]
# 4939    [12.2 oz]              []               [12.2 oz]
# 5138      [42 oz]              []          [42-oz, 42 oz]
# 5139      [42 oz]              []                      []
# 5140      [42 oz]              []                      []
# 5141      [42-oz]              []           [42-oz, 0 oz]
# 5142      [42-oz]              []           [42-oz, 0 oz]
# 5143      [42 oz]              []                      []
# 5144      [42-oz]              []           [42-oz, 0 oz]
# 5145           []              []                      []
# 5146     [0.2 oz]              []                      []
# 5147       [2 oz]              []                  [2-oz]
# 5148       [2 oz]              []                  [2-oz]
# 5149       [2 oz]              []                  [2-oz]
# 5704      [48 oz]              []                 [48 oz]
# 5705      [48 oz]              []                 [48 oz]
# 5706           []         [16-oz]            [9 oz, 9-oz]
# 5707      [65 oz]              []                 [65 oz]
# 5708     [2.5 oz]              []                [2.5 oz]
# 5709       [3 oz]              []                  [3 oz]
# 5710       [3 oz]              []                  [3 oz]
# 5711       [3 oz]              []                  [3 oz]
# 5712     [3.3-oz]        [3.3-oz]        [3.3-oz, 3.3 oz]
# 5713       [3-oz]          [3-oz]                  [3-oz]
# 5714           []              []                      []
# 5715       [4 oz]              []                  [4 oz]
# 5716     [5.5 oz]              []                [5.5 oz]
# 5717      [10 oz]              []                 [10 oz]
# 5718      [10 oz]              []                 [10 oz]
# 5719      [10 oz]              []                 [10 oz]
# 5720      [10 oz]              []                 [10 oz]
# 5721     [9.9 oz]              []                [9.9 oz]
# 5722       [9 oz]              []                  [9 oz]
# 5723    [10.3 oz]              []      [10.3-oz, 10.3 oz]
# 5724    [14.4 oz]              []               [14.4 oz]
# 5725      [13 oz]              []                 [13 oz]
# 5726      [11 oz]              []                 [11 oz]
# 5727      [11 oz]              []                 [11 oz]
# 5764    [11.5 oz]              []                      []
# 5765      [25 oz]              []                 [25 oz]
# 5766    [12.2 oz]              []               [12.2 oz]
# 5767      [11 oz]              []                 [11 oz]
# 5768    [12.5 oz]              []               [12.5 oz]
# 5769           []              []                      []
# 5770           []              []                      []
# 5771    [22.9 oz]              []               [22.9 oz]
# 5772    [20.5 oz]              []               [20.5 oz]
# 6028      [07 oz]              []                 [07-oz]
# 6029      [18 oz]              []          [18 oz, 18-oz]
# 6030      [42 oz]              []          [42-oz, 42 oz]
# 6324           []              []                      []
# 6325      [07 oz]              []                      []
# 6326       [5 oz]              []                  [5-oz]
# 6327       [14oz]              []                      []
# 6328      [75 oz]              []                 [75-oz]
# 6329           []              []                      []
# 6330           []              []                      []
# 6338      [07 oz]              []                 [07 oz]

# %%
customer_id = '5'
customer_name='%bedbathandbeyond%'
dateszs='2002-08-11'
attribut='shelf_weight_capacity'
curation_col = f'Q:{attribut}'
params = {'customer_id': customer_id,
          'customer_name':customer_name,
         'dateszs':dateszs,
         'attribute':attribut}

print('start')
dfs = query_from_file(file_name='../query/curated_all_attributes_date_one_attribute.sql', params=params)
print(len(dfs))
dfz=dfs[dfs['resolution'].astype(str)!='rules']
print(len(dfz))
dfh=dfz[dfz['custom_fields'].astype(str)!='None']
# dfz=dfz[dfz['buckets'].astype(str)=='Conduit Fittings, Replacement Parts, & Accessories']
print(len(dfh))
custom_field_df=pd.json_normalize(dfh['custom_fields'])
df=pd.concat([dfh.drop('custom_fields', axis=1), custom_field_df], axis = 1)
print(len(df))
# Out:
# start
# 35471
# 35172
# 35172
# 35360

# %%
print(len(dfs))
na=df[df['value'].astype(str)=='n/a']
print(len(na))
df=df[df['value'].astype(str)!='n/a']
print(len(df))
# Out:
# 35471
# 32074
# 3286

# %%
pat='''(?i)(\-)|(and)'''
df['match']=df['value'].apply(lambda x: re_extract(pat,str(x)))
val=df[(df['match'].astype(str)=='[]')&(df['external_id'].astype(str)!='nan')]
val['val']=val['value'].apply(lambda x: re.sub(r'(?i)(\s?lb)|(\,)|(\s?in)|(\.\d+)','',str(x)))
print(len(val))
# Out:
# 1536

# %%
import re

metric='lbs'
range_string = """
100 lbs and Greater
1 - 24 lbs
25 - 49 lbs
50 - 74 lbs
75 - 99 lbs
 """

range_params = {}
for range_entry in range_string.split('\n'):
    range_nums = re.findall('\d+', range_entry)
    if len(range_nums) > 0: 
        range_params[tuple(map(int, range_nums))] = range_entry.strip()


def  range_app(num_lst):
    updated_labels = []
    for num in num_lst:
        num = float(num)
        for range_param, range_label in range_params.items():
            if len(range_param) == 1:
                if num >= range_param[0]:
                    updated_labels.append(range_label)
            else:
                if num >= range_param[0] and num <= range_param[1]:
                    updated_labels.append(range_label)
    return updated_labels

# %%
val[curation_col]=val['val'].apply(lambda x: f"['{x}']").apply(lambda x: re.sub(r'\[','["',str(x))).apply(lambda x: re.sub(r'\]','"]',str(x))).apply(lambda x: re.sub(r',','","',str(x))).apply(lambda x: re.sub(r'""','"',str(x))).apply(lambda x: re.sub(r"'",'',str(x))).apply(lambda x: remove_duplicates([n.strip() for n in ast.literal_eval(x)])).apply(range_app).apply(lambda x: re.sub(r"\['",'["',str(x))).apply(lambda x: re.sub(r"'\]",'"]',str(x))).apply(lambda x: re.sub(r"'\s?,\s?'",'","',str(x))).apply(lambda x: re.sub(r"'\[",'[',str(x))).apply(lambda x: re.sub(r"\]'",']',str(x))).apply(lambda x: re.sub(r'\,\s',',',str(x))).apply(lambda x: remove_duplicates([n.strip() for n in ast.literal_eval(x)])) .apply(lambda x: re.sub(r"\['",'["',str(x))).apply(lambda x: re.sub(r"'\]",'"]',str(x))).apply(lambda x: re.sub(r"'\s?,\s?'",'","',str(x))).apply(lambda x: re.sub(r"'\[",'[',str(x))).apply(lambda x: re.sub(r"\]'",']',str(x)))
val[['external_id','value',curation_col]]
# Out:
#       external_id  value Q:shelf_weight_capacity
# 14386   200415917  30 lb         ["25 - 49 lbs"]
# 14387    61097711  50 lb         ["50 - 74 lbs"]
# 14388    69946464  50 lb         ["50 - 74 lbs"]
# 15253   200614298  22 lb          ["1 - 24 lbs"]
# 15256   200672308  10 lb          ["1 - 24 lbs"]
# ...           ...    ...                     ...
# 35434    69382796  30 lb         ["25 - 49 lbs"]
# 35435    69528087  30 lb         ["25 - 49 lbs"]
# 35436    69590742  35 lb         ["25 - 49 lbs"]
# 35437    40148830  40 lb         ["25 - 49 lbs"]
# 35438    67183449  40 lb         ["25 - 49 lbs"]
#
# [1536 rows x 3 columns]

# %%
match_shelf=val[['external_id',curation_col]]

# %%
def get_df_name(df):
    name =[x for x in globals() if globals()[x] is df][0]
    return name
def looks_good(customer, matches): 
    drive_path = f'G:/Shared drives/GroupBy Public/Customer Success/.Enrich/Platform Upload Trail/{customer}/_Ready For Upload' 
    matches.to_csv(f'{drive_path}/Bed Bath & Beyond --{get_df_name(matches)}-match_shelf{today}.csv',index=False) 
looks_good('Bed Bath & Beyond',match_shelf)

# %%
shelf=df[df['attribute'].astype(str)=='shelf_weight_capacity']
print(len(shelf))
na=shelf[shelf['value'].astype(str)=='n/a']
print(len(na))
val=shelf[shelf['value'].astype(str)!='n/a']
print(len(val))
# Out:
# 6192
# 5867
# 325

# %%
care=df[(df['attribute'].astype(str)=='rug_size')]
print(len(care))
print(len(care[care['value'].astype(str)=='n/a']))
# pat='''(.{0,10}(?:\d\'\s?x\s?\d+\'|\d+\'\s?round|\d+\'\s?rug.?runner|\d+\'\s?square|\d+\'\s?runner).{0,10})'''
# x,y=three(care,pat)
# Out:
# 10753
# 7309

# %%
# by
((?<!\d)(?:2)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?\s?x\s?(?:3)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:2)?)|((?:18|24)(?:\\?")?[^\w]x[^\w](?:36)(?:\\?")?)|
((?<!\d)(?:3)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:[45])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:6)?)|((?<!\d)42\\?"\s?x\s?66\\?")|
((?<!\d)(?:[7])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[6-9]|1[0-1])?(?:\d)?\s?x\s?(?:9)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[6-9])?)|((?<!\d)(?:[8])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?(?:\d)?\s?x\s?(?:1[0-1])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)|((?<!\d)(?:[7])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[6-9]|1[0-1])?(?:\d)?\s?x\s?(?:1[0-1])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)|((?<!\d)(?:[8])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?(?:\d)?\s?x\s?(?:9)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[6-9])?)|                      
((?<!\d)(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:7)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:6|9)?)|((?<!\d)(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:8)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)|
((?<!\d)(?:4)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:5|6)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[6-9])?)|((?<!\d)(?:3)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:6)?(?:\d)?\s?x\s?(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:6)?)|((?<!\d)(?:3)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:11)?(?:\d)?\s?x\s?(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:11|7)?)|    
((?<!\d)(?:6)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:9|8)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)|
((?<!\d)(?:7)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:9)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)|
((?<!\d)(?:10)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:14|13)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-5])?)|
((?<!\d)(?:12)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:15)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-5])?)|

# %%
# round
((?<!\d)(?:3)\'?[^\w]?x[^\w]?(?:3)\'?)|((?:3)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)3'?\s?[0-7][^\w]?x[^\w]?3'?\s?[0-7])|(3'?\s?x\s?(?:round|square))|
((?<!\d)(?:4)\'?[^\w]?x[^\w]?(?:4)\'?)|((?:4)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)4'?\s?[0-7][^\w]?x[^\w]?4'?\s?[0-7])|(4'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'4'')|
((?<!\d)(?:5)\'?[^\w]?x[^\w]?(?:5)\'?)|((?:5)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)5'?\s?[0-7][^\w]?x[^\w]?5'?\s?[0-7])|(5'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'5'')|
((?<!\d)(?:6)\'?[^\w]?x[^\w]?(?:6)\'?)|((?:6)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)6'?\s?[0-7][^\w]?x[^\w]?6'?\s?[0-7])|(6'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'6'')|
((?<!\d)(?:7)\'?[^\w]?x[^\w]?(?:7)\'?)|((?:7)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)7'?\s?[0-7][^\w]?x[^\w]?7'?\s?[0-7])|(7'?\s?x\s?(?:round|square))(sku.?size\'\:\s?\'7'')|
((?<!\d)(?:8)\'?[^\w]?x[^\w]?(?:8)\'?)|((?:8)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)8'?\s?[0-7][^\w]?x[^\w]?8'?\s?[0-7])|(8'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'8'')|
((?<!\d)(?:9)\'?[^\w]?x[^\w]?(?:9)\'?)|((?:9)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)9'?\s?[0-7][^\w]?x[^\w]?9'?\s?[0-7])|(9'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'9'')|

# %%
# runner
((?<!\d)(?:4)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:4)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:4)\'?\s?(?:2)?)|
((?<!\d)(?:5)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:5)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:5)\'?\s?(?:2)?)|
((?<!\d)(?:6)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:6)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:6)\'?\s?(?:2)?)|
((?<!\d)(?:7)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:7)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:7)\'?\s?(?:2)?)|
((?<!\d)(?:8)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:8)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:8)\'?\s?(?:2)?)|
((?<!\d)(?:9)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:9)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:9)\'?\s?(?:2)?)|
((?<!\d)(?:10)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:10)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:10)\'?\s?(?:2)?)|
((?<!\d)(?:11)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:11)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:11)\'?\s?(?:2)?)|
((?<!\d)(?:12)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:12)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:12)\'?\s?(?:2)?)|
((?<!\d)(?:1[3-9])\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:1[3-9])\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:1[3-9])\'?\s?(?:2)?)|

# %% [markdown]
# # N/A

# %%
# (?i)((?<!\d)(?:3)\'?[^\w]?x[^\w]?(?:3)\'?)|((?:3)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)3'?\s?[0-7][^\w]?x[^\w]?3'?\s?[0-7])|(3'?\s?x\s?(?:round|square))|((?<!\d)(?:4)\'?[^\w]?x[^\w]?(?:4)\'?)|((?:4)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)4'?\s?[0-7][^\w]?x[^\w]?4'?\s?[0-7])|(4'?\s?x\s?(?:round|square))((?<!\d)(?:5)\'?[^\w]?x[^\w]?(?:5)\'?)|((?:5)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)5'?\s?[0-7][^\w]?x[^\w]?5'?\s?[0-7])|(5'?\s?x\s?(?:round|square))|((?<!\d)(?:6)\'?[^\w]?x[^\w]?(?:6)\'?)|((?:6)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)6'?\s?[0-7][^\w]?x[^\w]?6'?\s?[0-7])|(6'?\s?x\s?(?:round|square))|((?<!\d)(?:7)\'?[^\w]?x[^\w]?(?:7)\'?)|((?:7)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)7'?\s?[0-7][^\w]?x[^\w]?7'?\s?[0-7])|(7'?\s?x\s?(?:round|square))|((?<!\d)(?:8)\'?[^\w]?x[^\w]?(?:8)\'?)|((?:8)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)8'?\s?[0-7][^\w]?x[^\w]?8'?\s?[0-7])|(8'?\s?x\s?(?:round|square))|((?<!\d)(?:9)\'?[^\w]?x[^\w]?(?:9)\'?)|((?:9)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)9'?\s?[0-7][^\w]?x[^\w]?9'?\s?[0-7])|(9'?\s?x\s?(?:round|square))|((?<!\d)(?:2)\'?(?:\s)?(?:[0-6])?\s?x\s?(?:3)\'?(?:\s)?(?:2)?)|((?<!\d)(?:3)\'?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:[45])\'?(?:\s)?(?:6)?)|((?<!\d)42\\?"\s?x\s?66\\?")|((?<!\d)(?:[7])\'?(?:\s)?(?:[6-9]|1[0-1])?(?:\d)?\s?x\s?(?:9)\'?(?:\s)?(?:[6-9])?)|((?<!\d)(?:[8])\'?(?:\s)?(?:0)?(?:\d)?\s?x\s?(?:1[0-1])\'?(?:\s)?(?:0)?)|((?<!\d)(?:[7])\'?(?:\s)?(?:[6-9]|1[0-1])?(?:\d)?\s?x\s?(?:1[0-1])\'?(?:\s)?(?:0)?)|((?<!\d)(?:[8])\'?(?:\s)?(?:0)?(?:\d)?\s?x\s?(?:9)\'?(?:\s)?(?:[6-9])?)|((?<!\d)(?:5)\'?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:7)\'?(?:\s)?(?:6|9)?)|((?<!\d)(?:5)\'?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:8)\'?(?:\s)?(?:0)?)|((?<!\d)(?:4)\'?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:5|6)\'?(?:\s)?(?:[6-9])?)|((?<!\d)(?:3)\'?(?:\s)?(?:6)?(?:\d)?\s?x\s?(?:5)\'?(?:\s)?(?:6)?)|((?<!\d)(?:3)\'?(?:\s)?(?:11)?(?:\d)?\s?x\s?(?:5)\'?(?:\s)?(?:11|7)?)|((?<!\d)(?:6)\'?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:9|8)\'?(?:\s)?(?:0)?)|((?<!\d)(?:5)\'?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:7)\'?(?:\s)?(?:0|10)?)|((?<!\d)(?:4)\'?(?:\s)?(?:11)?(?:\d)?\s?x\s?(?:7)\'?(?:\s)?(?:0|10)?)|((?<!\d)(?:7)\'?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:9)\'?(?:\s)?(?:0)?)|((?<!\d)(?:9)\'?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:12|13)\'?(?:\s)?(?:[0-5])?)|((?<!\d)(?:10)\'?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:14|13)\'?(?:\s)?(?:[0-5])?)|((?<!\d)(?:12)\'?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:15)\'?(?:\s)?(?:[0-5])?)|((?<!\d)(?:4)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:4)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:4)\'?\s?(?:2)?)|((?<!\d)(?:5)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:5)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:5)\'?\s?(?:2)?)|((?<!\d)(?:6)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:6)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:6)\'?\s?(?:2)?)|((?<!\d)(?:7)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:7)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:7)\'?\s?(?:2)?)|((?<!\d)(?:8)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:8)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:8)\'?\s?(?:2)?)|((?<!\d)(?:9)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:9)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:9)\'?\s?(?:2)?)|((?<!\d)(?:10)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:10)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:10)\'?\s?(?:2)?)|((?<!\d)(?:11)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:11)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:11)\'?\s?(?:2)?)|((?<!\d)(?:12)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:12)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:12)\'?\s?(?:2)?)|((?<!\d)(?:1[3-9])\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:1[3-9])\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:1[3-9])\'?\s?(?:2)?)   
trip=r'''(?i)((?<!\d)(?:4)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:4)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:4)\'?\s?(?:2)?)|((?<!\d)(?:5)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:5)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:5)\'?\s?(?:2)?)|((?<!\d)(?:6)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:6)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:6)\'?\s?(?:2)?)|((?<!\d)(?:7)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:7)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:7)\'?\s?(?:2)?)|((?<!\d)(?:8)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:8)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:8)\'?\s?(?:2)?)|((?<!\d)(?:9)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:9)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:9)\'?\s?(?:2)?)|((?<!\d)(?:10)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:10)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:10)\'?\s?(?:2)?)|((?<!\d)(?:11)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:11)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:11)\'?\s?(?:2)?)|((?<!\d)(?:12)\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:12)\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:12)\'?\s?(?:2)?)|((?<!\d)(?:1[3-9])\'\s?\d{0,2}\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?:2)\'?[^\w]?x[^\w]?(?:1[3-9])\'?(?:.{0,10}\s?[A-z\/\s]{0,20}\s?(?:indoor)?\s?rug)?)|((?:2)\'?\s?(?:7)?[^\w]?x[^\w]?(?:1[3-9])\'?\s?(?:2)?)|((?<!\d)(?:3)\'?[^\w]?x[^\w]?(?:3)\'?)|((?:3)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)3'?\s?[0-7][^\w]?x[^\w]?3'?\s?[0-7])|(3'?\s?x\s?(?:round|square))|((?<!\d)(?:4)\'?[^\w]?x[^\w]?(?:4)\'?)|((?:4)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)4'?\s?[0-7][^\w]?x[^\w]?4'?\s?[0-7])|(4'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'4'')|((?<!\d)(?:5)\'?[^\w]?x[^\w]?(?:5)\'?)|((?:5)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)5'?\s?[0-7][^\w]?x[^\w]?5'?\s?[0-7])|(5'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'5'')|((?<!\d)(?:6)\'?[^\w]?x[^\w]?(?:6)\'?)|((?:6)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)6'?\s?[0-7][^\w]?x[^\w]?6'?\s?[0-7])|(6'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'6'')|((?<!\d)(?:7)\'?[^\w]?x[^\w]?(?:7)\'?)|((?:7)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)7'?\s?[0-7][^\w]?x[^\w]?7'?\s?[0-7])|(7'?\s?x\s?(?:round|square))(sku.?size\'\:\s?\'7'')|((?<!\d)(?:8)\'?[^\w]?x[^\w]?(?:8)\'?)|((?:8)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)8'?\s?[0-7][^\w]?x[^\w]?8'?\s?[0-7])|(8'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'8'')|((?<!\d)(?:9)\'?[^\w]?x[^\w]?(?:9)\'?)|((?:9)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)9'?\s?[0-7][^\w]?x[^\w]?9'?\s?[0-7])|(9'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'9'')|((?<!\d)(?:2)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?\s?x\s?(?:3)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:2)?)|((?:18|24)(?:\\?")?[^\w]x[^\w](?:36)(?:\\?")?)|((?<!\d)(?:3)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:[45])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:6)?)|((?<!\d)42\\?"\s?x\s?66\\?")|((?<!\d)(?:[7])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[6-9]|1[0-1])?(?:\d)?\s?x\s?(?:9)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[6-9])?)|((?<!\d)(?:[8])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?(?:\d)?\s?x\s?(?:1[0-1])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)|((?<!\d)(?:[7])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[6-9]|1[0-1])?(?:\d)?\s?x\s?(?:1[0-1])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)|((?<!\d)(?:[8])(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?(?:\d)?\s?x\s?(?:9)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[6-9])?)|((?<!\d)(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:7)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:6|9)?)|((?<!\d)(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:8)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)|((?<!\d)(?:4)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:5|6)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[6-9])?)|((?<!\d)(?:3)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:6)?(?:\d)?\s?x\s?(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:6)?)|((?<!\d)(?:3)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:11)?(?:\d)?\s?x\s?(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:11|7)?)|((?<!\d)(?:6)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:9|8)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)|((?<!\d)(?:7)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:9)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)|((?<!\d)(?:10)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:14|13)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-5])?)|((?<!\d)(?:12)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:15)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-5])?)|()'''
x,y,na=three(care,trip)
# Out:
# Start
# values: 8626
# no values: 2127

# %%
val=x[x['value'].astype(str)=='n/a']
print(len(val))
na=y[y['value'].astype(str)!='n/a']
print(len(na))
# Out:
# 5212
# 30

# %%
na['value'].value_counts()
# Out:
# 9' x 12'           14
# 7' Runner           4
# 8' Round/Square     2
# 4' Round/Square     2
# 6' Round/Square     2
# 8' x 10'            1
# 4' Runner           1
# 4' x 6'             1
# 3' x 5'             1
# 5' x 8'             1
# 7' Round/Square     1
# Name: value, dtype: int64

# %%
# na[(na['value'].astype(str)!="5' Round/Square")]['product_name'].value_counts()

# %% [markdown]
# # runners

# %%
# eight_by_ten=care[care['value'].astype(str)=="4' Runner"]
pat='''((?<!\.)(?<!\d)(?:7)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\d)(?:2|2\.25)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?:7)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?:2|2\.25)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\d)7)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2))?)|((?<!\.)(?<!\d)(?:7)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?)?[^\w]?x[^\w]?(?<!\d)(?:2|2\.25)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|(2\'\s?x\s?7\')'''                            
four_runner,middle,na=three(care,pat)
# Out:
# Start
# values: 229
# No name but call outs: 63
# no values: 10461

# %%
# print(len(care[care['value'].astype(str)=="4' Runner"]))
# print(na['value'].value_counts())
print(len(na[(na['value'].astype(str)=='n/a')]))
na[(na['value'].astype(str)=='n/a')&((na['m_name'].astype(str)!='''[]''')|(na['m_desc'].astype(str)!='''[]''')|(na['m_custom'].astype(str)!='''[]'''))]
# Out:
# 7053
# Empty DataFrame
# Columns: [attribute, buckets, bucket_id, value, customer_name, external_id, product_name, long_desc, curated_date, resolution, curation_tasks.curated_by, custom_fields, m_name, m_desc, m_custom]
# Index: []

# %%
# print(len(care[care['value'].astype(str)=="4' Runner"]))
# print(middle['value'].value_counts())
# middle[(middle['value'].astype(str)=='n/a')]

# %%
# print(len(care[care['value'].astype(str)=="4' Runner"]))
# print(four_runner['value'].value_counts())
# four_runner[(four_runner['value'].astype(str)=='n/a')&(four_runner['value'].astype(str)!='''6' Runner''')]['product_name'].value_counts()
# four_runner

# %%
def run(num_one,num_two):        
    pat=fr'''((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:{num_one})(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:{num_two})(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:{num_one})(?:(?:\\?'|\s?ft\.?|'[^\w]foot|'\s?0"?))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:{num_two})(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\')(?<!\' )(?<!\d)10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:{num_two}))?)|((?<!\.)(?<!\')(?<!\d)(?<!\' )(?:{num_one})(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?)?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:{num_two})(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:{num_two})|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:{num_two})'?\s?x\s?{num_one}\'?)'''                        
    print(pat)

run('4','''2|2\.25|2'?\s?0"?''')
# Out:
# ((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:4)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:4)(?:(?:\\?'|\s?ft\.?|'[^\w]foot|'\s?0"?))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\')(?<!\' )(?<!\d)10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:2|2\.25|2'?\s?0"?))?)|((?<!\.)(?<!\')(?<!\d)(?<!\' )(?:4)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?)?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2|2\.25|2'?\s?0"?)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)'?\s?x\s?4\'?)

# %%
#run('4',2)
print("4' Runner")
eight_by_ten=x[x['value'].astype(str)=="4' Runner"]
pat='''((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:4)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:4)(?:(?:\\?'|\s?ft\.?|'[^\w]foot|'\s?0"?))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\')(?<!\' )(?<!\d)10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:2|2\.25|2'?\s?0"?))?)|((?<!\.)(?<!\')(?<!\d)(?<!\' )(?:4)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?)?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2|2\.25|2'?\s?0"?)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)'?\s?x\s?4\'?)'''                            
four_first,four_mid,four_na=three(care,pat)

print("5' Runner")
eight_by_ten=x[x['value'].astype(str)=="5' Runner"]
pat='''((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:5)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:5)(?:(?:\\?'|\s?ft\.?|'[^\w]foot|'\s?0"?))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\')(?<!\' )(?<!\d)10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:2|2\.25|2'?\s?0"?))?)|((?<!\.)(?<!\')(?<!\d)(?<!\' )(?:5)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?)?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2|2\.25|2'?\s?0"?)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)'?\s?x\s?5\'?)'''                            
five_first,five_mid,five_na=three(care,pat)

print("6' Runner")
eight_by_ten=x[x['value'].astype(str)=="6' Runner"]
pat='''((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:6)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:6)(?:(?:\\?'|\s?ft\.?|'[^\w]foot|'\s?0"?))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\')(?<!\' )(?<!\d)10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:2|2\.25|2'?\s?0"?))?)|((?<!\.)(?<!\')(?<!\d)(?<!\' )(?:6)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?)?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2|2\.25|2'?\s?0"?)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)'?\s?x\s?6\'?)'''                            
six_first,six_mid,six_na=three(care,pat)

print("7' Runner")
eight_by_ten=x[x['value'].astype(str)=="7' Runner"]
pat='''((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:7)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:7)(?:(?:\\?'|\s?ft\.?|'[^\w]foot|'\s?0"?))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\')(?<!\' )(?<!\d)10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:2|2\.25|2'?\s?0"?))?)|((?<!\.)(?<!\')(?<!\d)(?<!\' )(?:7)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?)?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2|2\.25|2'?\s?0"?)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)'?\s?x\s?7\'?)'''                            
seven_first,seven_mid,seven_na=three(care,pat)

print("8' Runner")
eight_by_ten=x[x['value'].astype(str)=="8' Runner"]
pat='''((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:8)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:8)(?:(?:\\?'|\s?ft\.?|'[^\w]foot|'\s?0"?))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\')(?<!\' )(?<!\d)10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:2|2\.25|2'?\s?0"?))?)|((?<!\.)(?<!\')(?<!\d)(?<!\' )(?:8)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?)?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2|2\.25|2'?\s?0"?)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)'?\s?x\s?8\'?)'''
eight_first,eight_mid,eight_na=three(care,pat)

print("9' Runner")
eight_by_ten=x[x['value'].astype(str)=="9' Runner"]
pat='''((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:9)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:9)(?:(?:\\?'|\s?ft\.?|'[^\w]foot|'\s?0"?))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\')(?<!\' )(?<!\d)10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:2|2\.25|2'?\s?0"?))?)|((?<!\.)(?<!\')(?<!\d)(?<!\' )(?:9)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?)?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2|2\.25|2'?\s?0"?)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)'?\s?x\s?9\'?)'''                            
nine_first,nine_mid,nine_na=three(care,pat)

print("10' Runner")
eight_by_ten=x[x['value'].astype(str)=="10' Runner"]
pat='''((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:10)(?:(?:\\?'|\s?ft\.?|'[^\w]foot|'\s?0"?))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\')(?<!\' )(?<!\d)10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:2|2\.25|2'?\s?0"?))?)|((?<!\.)(?<!\')(?<!\d)(?<!\' )(?:10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?)?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2|2\.25|2'?\s?0"?)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)'?\s?x\s?10\'?)'''                            
ten_first,ten_mid,ten_na=three(care,pat)

print("11' Runner")
eight_by_ten=x[x['value'].astype(str)=="11' Runner"]
pat='''((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:11)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:11)(?:(?:\\?'|\s?ft\.?|'[^\w]foot|'\s?0"?))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\')(?<!\' )(?<!\d)10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:2|2\.25|2'?\s?0"?))?)|((?<!\.)(?<!\')(?<!\d)(?<!\' )(?:11)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?)?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2|2\.25|2'?\s?0"?)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)'?\s?x\s?11\'?)'''                            
el_first,el_mid,el_na=three(care,pat)

print("12' Runner")
eight_by_ten=x[x['value'].astype(str)=="12' Runner"]
pat='''((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:12)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:12)(?:(?:\\?'|\s?ft\.?|'[^\w]foot|'\s?0"?))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\')(?<!\' )(?<!\d)10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:2|2\.25|2'?\s?0"?))?)|((?<!\.)(?<!\')(?<!\d)(?<!\' )(?:12)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?)?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2|2\.25|2'?\s?0"?)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)'?\s?x\s?12\'?)'''                            
tw_first,tw_mid,tw_na=three(care,pat)

print("13' Runner")
eight_by_ten=x[x['value'].astype(str)=="13' Runner"]
pat='''((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:1[3-9])(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?\d(0, 2))?\s?(?:indoor\/outdoor|hand.?crafted|hand.?woven|rag|Multicolor.?Rag|rug)?\s?[^\w]Runner)|((?<!\.)(?<!\')(?<!\' )(?<!\d)(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:1[3-9])(?:(?:\\?'|\s?ft\.?|'[^\w]foot|'\s?0"?))?(?:.(0, 10)\s?[A-z\/\s](0, 20)\s?(?:indoor)?\s?rug)?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?[^\w]?x[^\w]?(?:(?<!\')(?<!\' )(?<!\d)10)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:2|2\.25|2'?\s?0"?))?)|((?<!\.)(?<!\')(?<!\d)(?<!\' )(?:1[3-9])(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:7)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?)?[^\w]?x[^\w]?(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)\s?(?:2|2\.25|2'?\s?0"?)|(?:\\?'|\s?ft\.?|\\?"|[^\w]foot))?)|((?<!\.)(?<!\d)(?<!\')(?<!\' )(?:2|2\.25|2'?\s?0"?)'?\s?x\s?1[3-9]\'?)'''                            
th_first,th_mid,th_na=three(care,pat)
# Out:
# 4' Runner
# Start
#
# values: 358
# No name but call outs: 9
# no values: 10386
#
# 5' Runner
# Start
#
# values: 326
# No name but call outs: 44
# no values: 10383
#
# 6' Runner
# Start
#
# values: 188
# No name but call outs: 99
# no values: 10466
#
# 7' Runner
# Start
#
# values: 301
# No name but call outs: 59
# no values: 10393
#
# 8' Runner
# Start
#
# values: 148
# No name but call outs: 26
# no values: 10579
#
# 9' Runner
# Start
#
# values: 279
# No name but call outs: 3
# no values: 10471
#
# 10' Runner
# Start
#
# values: 76
# No name but call outs: 6
# no values: 10671
#
# 11' Runner
# Start
#
# values: 287
# No name but call outs: 40
# no values: 10426
#
# 12' Runner
# Start
#
# values: 144
# No name but call outs: 26
# no values: 10583
#
# 13' Runner
# Start
#
# values: 318
# No name but call outs: 13
# no values: 10422

# %%
# four_mid#['m_name'].explode().value_counts()

# %% [markdown]
# # by

# %%
def un(num_one,num_two,num_three,num_four):
    pat=f'''(?i)((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:{num_one})((?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)\s?(?:{num_two}))?\[^\w\]?x[^\w]?(?:{num_three}((?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)\s?(?:{num_four}))?)|()'''
    print(pat)
    
un(2,'[0-6]',3,2)

# %%
# Out:
# (?i)((?<!\d)(?:2)(?:\?'|\s?ft\.?|\?"|[^\w]foot)?\s?(?:[0-6])?\[^\w\]?x[^\w]?(?:3(?:\?'|\s?ft\.?|\?"|[^\w]foot)?\s?(?:2)?)|()

# %%
print("2x3")
#un(2,'[0-6]',3,2)
eight_by_ten=x[x['value'].astype(str)=="2' x 3'"]
pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:{num_one})(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:[6-9]|1[0-1])?[^\w]?x[^\w]?(?:{num_two})(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:[6-9])?)|((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:{num_one})(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:0)?[^\w]?x[^\w]?(?:{num_two})(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:0)?)|((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:{num_one})(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:[6-9]|1[0-1])?[^\w]?x[^\w]?(?:{num_two})(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:0)?)|((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:{num_one})(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:0)?[^\w]?x[^\w]?(?:{num_two})(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:[6-9])?)'''                            
by_tt_first,by_tt_mid,by_tt_na=three(care,pat)
# Out:
# 2x3
# Start
#
# values: 641
# No name but call outs: 1091
# no values: 9021

# %%
by_tt_mid['value'].value_counts()
# Out:
# n/a                  850
# 4' x 6'               43
# 5' x 8'               35
# 6' x 9'               33
# 8' x 10'              26
# 6' Round/Square       19
# 9' x 12'              19
# 2' x 3'               19
# 8' Round/Square       17
# 5' x 7'               12
# 4' Round/Square        4
# 10' x 14'              3
# 3' x 5'                3
# 8' Runner              2
# 10'+ Round/Square      2
# 5' Round/Square        2
# 12' x 15'              1
# 7' x 9'                1
# Name: value, dtype: int64

# %%
# by_tt_mid[by_tt_mid['value'].astype(str)=="3' x 5'"]

# %%
print("2x3")
# good
eight_by_ten=x[x['value'].astype(str)=="2' x 3'"]
pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:2)((?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)\s?(?:[0-6]))?\s?x\s?(?:3)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot|'\s?0"?)?\s?)|((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:18|24)(?:\\?\s?"|"|.?inch)?[^\w]?x[^\w]?(?:36)(?:\\?\s?"|".?inch)?)|((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:36)(?:\\?\s?"|".?inch)?[^\w]?x[^\w]?(?:18|24)(?:\\?"|"|.?inch)?[^\w])|((?<!\d)(?<!\')(?<!'\s)(?<!\.)2\s?(?:\'|\\?")?\s?x\s?3\s?(?:\'|\\?")?)'''                            
by_tt_first,by_tt_mid,by_tt_na=three(care,pat)

print("3x5")
#un(3,'[0-6]','[45]',6)
eight_by_ten=x[x['value'].astype(str)=="3' x 5'"]
pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:3)(?:(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?(?:\s[0-6])?)?[^\w]?x[^\w]?(?:[45])(?:(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s?[0-6])?))|((?<!\d)(?<!\')(?<!'\s)(?<!\.)3\s?(?:\'|\\?")?\s?x\s?5\s?(?:\'|\\?")?)|((?:42)(?:\\?\s?"|"|.?inch)?[^\w]?x[^\w]?(?:66)(?:\\?\s?"|".?inch)?)|([^\w](?:66)(?:\\?\s?"|".?inch)?^\w]?x[^\w]?(?:42)(?:\\?\s?"|"|.?inch)?[^\w])'''                            
by_tf_first,by_tf_mid,by_tf_na=three(care,pat)


# print("7x9")
# #un('[7]','[6-9]|1[0-1]','9','[6-9]')
# # un('[7]','[6-9]|1[0-1]','1[0-1]','0')
# eight_by_ten=x[x['value'].astype(str)=="8' x 10'"]
# pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:[7])(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:[6-9]|1[0-1])?[^\w]?x[^\w]?(?:9)(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:[6-9])?)|((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:[7])(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:[6-9]|1[0-1])?[^\w]?x[^\w]?(?:1[0-1])(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:0)?)'''                                
# by_et_first,by_et_mid,by_et_na=three(care,pat)

print("7x9")
#un('7','[0-6]','9','0')
eight_by_ten=x[x['value'].astype(str)=="7' x 9'"]
pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:7)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:9)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)'''                            
by_sn_first,by_sn_mid,by_sn_na=three(care,pat)

print("8x10")
# un('[8]','0','1[0-1]','0')
# un('[8]','0','9','[6-9]')
eight_by_ten=x[x['value'].astype(str)=="8' x 10'"]
pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:[8])(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:0)?[^\w]?x[^\w]?(?:1[0-1])(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:0)?)|((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:[8])(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:0)?[^\w]?x[^\w]?(?:9)(?:\\?\s?'|\s?ft\.?|\\?\s?"|[^\w]foot)?\s?(?:[6-9])?)'''                                
by_et_first,by_et_mid,by_et_na=three(care,pat)

# print("5x7")
# # un(5,'[0-6]','7','6|9')
# eight_by_ten=x[x['value'].astype(str)=="5' x 8'"]
# pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:7)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:6|9)?)'''                            
# by_fe_first,by_two_mid,by_two_na=three(care,pat)

print("5x7")
#un('5','[0-6]','7','0|10')
# un('4','11','7','0|10')
eight_by_ten=x[x['value'].astype(str)=="5' x 7'"]
pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:7)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0|10)?)|((?<!\d)(?:4)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:11)?(?:\d)?\s?x\s?(?:7)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0|10)?)'''                            
by_fs_first,by_fs_mid,by_fs_na=three(care,pat)


print("5x8")
# un(5,'[0-6]','8','0')
eight_by_ten=x[x['value'].astype(str)=="5' x 8'"]
pat='''((?<!\d)(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:8)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)'''                            
by_fe_first,by_two_mid,by_two_na=three(care,pat)

print("4x6")
# un(4,'[0-6]','5|6','[6-9]')
# un(3,'6','5','6')
# un(3,'11','5','11|7')
eight_by_ten=x[x['value'].astype(str)=="4' x 6'"]
pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:4)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:5|6)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[6-9])?)|((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:3)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?\s?(?:6)\s?x\s?(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?\s?(?:[6-9|1[0-6]]))|((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:3)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?\s?(?:11)(?:\d)?\s?x\s?(?:5)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?\s?(?:11|7))'''                            
by_fx_first,by_fx_mid,by_fx_na=three(care,pat)

print("6x9")
# un(6,'[0-6]','9|8','0')
eight_by_ten=x[x['value'].astype(str)=="6' x 9'"]
pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:6)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:9|8)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)'''                            
by_xn_first,by_xn_mid,by_xn_na=three(care,pat)

print("9x12")
# un('9','[0-6]','12|13','[0-5]')
eight_by_ten=x[x['value'].astype(str)=="9' x 12'"]
pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:9)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:12)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:0)?)'''                            
by_nt_first,by_nt_mid,by_nt_na=three(care,pat)

print("10x14")
#un('10','[0-6]','14|13','[0-5]')
eight_by_ten=x[x['value'].astype(str)=="10' x 14'"]
pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:10)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:14|13)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-5])?)'''                            
by_tfou_first,by_tfou_mid,by_tfou_na=three(care,pat)

print("12x15")
#un('12','[0-6]','15','[0-5]')
eight_by_ten=x[x['value'].astype(str)=="12' x 15'"]
pat='''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:12)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-6])?(?:\d)?\s?x\s?(?:15)(?:\\?'|\s?ft\.?|\\?"|[^\w]foot)?(?:\s)?(?:[0-5])?)'''                            
by_twfif_first,by_twfif_mid,by_twfif_na=three(care,pat)
# Out:
# 2x3
# Start
#
# values: 270
# No name but call outs: 565
# no values: 9918
#
# 3x5
# Start
#
# values: 324
# No name but call outs: 614
# no values: 9815
#
# 7x9
# Start
#
# values: 169
# No name but call outs: 43
# no values: 10541
#
# 8x10
# Start
#
# values: 383
# No name but call outs: 55
# no values: 10315
#
# 5x7
# Start
#
# values: 471
# No name but call outs: 64
# no values: 10218
#
# 5x8
# Start
#
# values: 184
# No name but call outs: 135
# no values: 10434
#
# 4x6
# Start
#
# values: 253
# No name but call outs: 246
# no values: 10254
#
# 6x9
# Start
#
# values: 401
# No name but call outs: 352
# no values: 10000
#
# 9x12
# Start
#
# values: 1
# No name but call outs: 14
# no values: 10738
#
# 10x14
# Start
#
# values: 0
# No name but call outs: 3
# no values: 10750
#
# 12x15
# Start
#
# values: 0
# No name but call outs: 0
# no values: 10753

# %%
by_tfou_first['value'].value_counts()
# Out:
# Series([], Name: value, dtype: int64)

# %%
by_et_first[by_et_first['value'].astype(str)=="3' x 5'"]
# Out:
# Empty DataFrame
# Columns: [attribute, buckets, bucket_id, value, customer_name, external_id, product_name, long_desc, curated_date, resolution, curation_tasks.curated_by, custom_fields, m_name, m_desc, m_custom]
# Index: []

# %% [markdown]
# # Round/Square

# %%
def roun(num_one,num_two):
    pat=f'''((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:{num_one})\s?\'?[^\w]?x[^\w]?(?:{num_one})\s?\'?)|((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:{num_one})\s?\'?\s?(?:{num_two})?[^\w]?(?:\s?half\s?)?round)|((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:{num_one})\s?\'?\s?{num_two}[^\w]?x[^\w]?(?:{num_one})\s?'?\s?{num_two})|((?<!\d)(?<!\')(?<!'\s)(?<!\.)(?:{num_one})\s?'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'(?:{num_one})'')|(SKU_SIZE[^\w]{0,4}(?:{num_one})\s?\'?(?:{num_two})?"?\s?(?:round|square)'''       
    print(pat)
    
roun(8,'[0-7]')

# %%
# Out:
# ((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:8)\s?'?[^\w]?x[^\w]?(?:8)\s?'?)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:8)\s?'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:8)\s?'?\s?[0-7][^\w]?x[^\w]?(?:8)\s?'?\s?[0-7])|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:8)\s?'?\s?x\s?(?:round|square))|(sku.?size'\:\s?'(?:8)'')|(SKU_SIZE[^\w](0, 4)(?:8)\s?'?(?:[0-7])?"?\s?(?:round|square)

# %%
print('three')
eight_by_ten=x[x['value'].astype(str)=="3' Round/Square"]
pat='''(?i)((?<!\d)(?:3)\'?[^\w]?x[^\w]?(?:3)\'?)|((?:3)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)3'?\s?[0-7][^\w]?x[^\w]?3'?\s?[0-7])|(3'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'3'')|()'''                            
three_round,na_three=three(eight_by_ten,pat)
# Out:
# three
# Start
# values: 37
# no values: 0

# %%
print('three')
eight_by_ten=x[x['value'].astype(str)=="3' Round/Square"]
pat='''((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:3)\s?'?[^\w]?x[^\w]?(?:3)\s?'?)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:3)\s?'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:3)\s?'?\s?[0-7][^\w]?x[^\w]?(?:3)\s?'?\s?[0-7])|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:3)\s?'?\s?x\s?(?:round|square))|(sku.?size'\:\s?'(?:3)'')|(SKU_SIZE[^\w](0, 4)(?:3)\s?'?(?:[0-7])?"?\s?(?:round|square))'''                            
three_round_first,three_round_mid,na_three=three(care,pat)

print('four')
eight_by_ten=x[x['value'].astype(str)=="4' Round/Square"]
pat='''((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:4)\s?'?[^\w]?x[^\w]?(?:4)\s?'?)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:4)\s?'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:4)\s?'?\s?[0-7][^\w]?x[^\w]?(?:4)\s?'?\s?[0-7])|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:4)\s?'?\s?x\s?(?:round|square))|(sku.?size'\:\s?'(?:4)'')|(SKU_SIZE[^\w](0, 4)(?:4)\s?'?(?:[0-7])?"?\s?(?:round|square))'''                            
four_round,four_round_mid,na_four=three(care,pat)

print('five')
eight_by_ten=x[x['value'].astype(str)=="5' Round/Square"]
pat='''((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:5)\s?'?[^\w]?x[^\w]?(?:5)\s?'?)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:5)\s?'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:5)\s?'?\s?[0-7][^\w]?x[^\w]?(?:5)\s?'?\s?[0-7])|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:5)\s?'?\s?x\s?(?:round|square))|(sku.?size'\:\s?'(?:5)'')|(SKU_SIZE[^\w](0, 4)(?:5)\s?'?(?:[0-7])?"?\s?(?:round|square))'''                            
five_round,five_round_mid,na_five=three(care,pat)

print('six')
eight_by_ten=x[x['value'].astype(str)=="6' Round/Square"]
pat='''((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:6)\s?'?[^\w]?x[^\w]?(?:6)\s?'?)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:6)\s?'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:6)\s?'?\s?[0-7][^\w]?x[^\w]?(?:6)\s?'?\s?[0-7])|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:6)\s?'?\s?x\s?(?:round|square))|(sku.?size'\:\s?'(?:6)'')|(SKU_SIZE[^\w](0, 4)(?:6)\s?'?(?:[0-7])?"?\s?(?:round|square))'''                            
six_round,six_round_mid,na_six=three(care,pat)

print('seven')
eight_by_ten=x[x['value'].astype(str)=="7' Round/Square"]
pat='''((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:7)\s?'?[^\w]?x[^\w]?(?:7)\s?'?)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:7)\s?'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:7)\s?'?\s?[0-7][^\w]?x[^\w]?(?:7)\s?'?\s?[0-7])|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:7)\s?'?\s?x\s?(?:round|square))|(sku.?size'\:\s?'(?:7)'')|(SKU_SIZE[^\w](0, 4)(?:7)\s?'?(?:[0-7])?"?\s?(?:round|square))'''                            
seven_round,seven_round_mid,na_seven=three(care,pat)

print('eight')
eight_by_ten=x[x['value'].astype(str)=="8' Round/Square"]
pat='''((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:8)\s?'?[^\w]?x[^\w]?(?:8)\s?'?)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:8)\s?'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:8)\s?'?\s?[0-7][^\w]?x[^\w]?(?:8)\s?'?\s?[0-7])|((?<!\d)(?<!')(?<!'\s)(?<!\.)(?:8)\s?'?\s?x\s?(?:round|square))|(sku.?size'\:\s?'(?:8)'')|(SKU_SIZE[^\w](0, 4)(?:8)\s?'?(?:[0-7])?"?\s?(?:round|square))'''                            
eight_round,eight_round_mid,na_eight=three(care,pat)

print('nine')
eight_by_ten=x[x['value'].astype(str)=="9' Round/Square"]
pat='''((?<!\d)(?:9)\'?[^\w]?x[^\w]?(?:9)\'?)|((?:9)\'?\s?(?:[0-7])?[^\w]?(?:\s?half\s?)?round)|((?<!\d)9'?\s?[0-7][^\w]?x[^\w]?9'?\s?[0-7])|(9'?\s?x\s?(?:round|square))|(sku.?size\'\:\s?\'9'')'''                            
nine_round,nine_round_mid,na_nine=three(care,pat)
# Out:
# three
# Start
#
# values: 39
# No name but call outs: 21
# no values: 10693
#
# four
# Start
#
# values: 59
# No name but call outs: 13
# no values: 10681
#
# five
# Start
#
# values: 204
# No name but call outs: 78
# no values: 10471
#
# six
# Start
#
# values: 86
# No name but call outs: 46
# no values: 10621
#
# seven
# Start
#
# values: 188
# No name but call outs: 48
# no values: 10517
#
# eight
# Start
#
# values: 91
# No name but call outs: 142
# no values: 10520
#
# nine
# Start
#
# values: 3
# No name but call outs: 103
# no values: 10647

# %%
origin=df[df['attribute'].astype(str)=='origin']
print(len(origin))
origin['curated_date']=pd.to_datetime(origin['curated_date'])
no=origin[(origin['curated_date']>='11-01-2022')&(origin['curated_date']<='11-30-2022')]
nov=no[no['resolution'].astype(str)=='standard']
print(len(nov))
# Out:
# 64403
# 54832

# %%
origin['value'].value_counts()
# Out:
# n/a                               44837
# Imported                          15474
# Made in the USA                    4029
# ["Imported","Made in the USA"]       63
# Name: value, dtype: int64

# %%
trip=r'''(?i)(n\/a)|()''' 
nov['values']=nov['value'].apply(lambda x: re_extract(trip,str(x)))
mach=nov[nov['values'].astype(str)!='[]']
print(len(mach))
# Out:
# 38971

# %%
x,y=three(mach,'''(\b(?:united.?states|united.?states.?of.?america|USA(?!.glass)(?!opoly)|AMerica|made.?in.?(?:us|u\.s\.))\b)|(imported)|(made.?in.?(?:canada|turkey|china|france|india|germany|italy|the.?uk|poland|malaysia|belgium|vienna|pakistan))|(.{0,10}(?<!hand.)(?<!hand)made(?!.for)(?!.out)(?!.by)(?!.of)(?!.with)(?!.from).{0,10})|(.{0,10}\busa(?!.glass)\b.{0,10})''')
# Out:
# values: 1618
# no values: 37353

# %%
x

# %%
imp=nov[nov['value'].astype(str)=='Imported']
print(len(imp))
na=nov[nov['value'].astype(str)=='n/a']
print(len(na))
usa=nov[nov['value'].astype(str)=='Made in the USA']
print(len(usa))
# Out:
# 0
# 0
# 0

# %%
nov['value'].value_counts()
# Out:
# Series([], Name: value, dtype: int64)

# %%
# trip=r'''(?i)(imported)|(made in Canada)|(euro.?sham)|(made.?in)|()''' 
trip=r'''(?i)(\b(?:united.?states|united.?states.?of.?america|USA(?!.glass)(?!opoly)|AMerica|made.?in.?(?:us|u\.s\.))\b)|(imported)|(made.?in.?(?:canada|turkey|china|france|india|germany|italy|the.?uk|poland|malaysia|belgium|vienna|pakistan))|(.{0,10}(?<!hand.)(?<!hand)made(?!.for)(?!.out)(?!.by)(?!.of)(?!.with)(?!.from).{0,10})|(.{0,10}\busa(?!.glass)\b.{0,10})|()''' 
usa['m_name']=usa['product_name'].apply(lambda x: re_extract(trip,str(x)))
usa['m_desc']=usa['long_desc'].apply(lambda x: re_extract(trip,str(x)))
usa['m_custom']=usa['custom_fields'].apply(lambda x: re_extract(trip,str(x)))
imported=usa[(usa['m_name'].astype(str)!='[]')|(usa['m_desc'].astype(str)!='[]')|(usa['m_custom'].astype(str)!='[]')]
print(len(imported))
# Out:
# 2891

# %%
# imported#[['external_id','m_name','m_desc','m_custom']][0:500]

# %%
impor=na[(na['m_name'].astype(str)=='[]')&(na['m_desc'].astype(str)=='[]')&(na['m_custom'].astype(str)=='[]')]
print(len(impor))
# Out:
# 37358

# %%
impor['value'].explode().value_counts()
# Out:
# n/a    37358
# Name: value, dtype: int64

# %%
trip=r'''(?i)((.{0,10}(?<!hand.)(?<!hand)made(?!.for)(?!.out)(?!.by)(?!.of)(?!.with)(?!.from).{0,10})|(.{0,10}\busa(?!.glass)\b.{0,10}))|()''' 
impor['m_name']=impor['product_name'].apply(lambda x: re_extract(trip,str(x)))
print('one')
impor['m_desc']=impor['long_desc'].apply(lambda x: re_extract(trip,str(x)))
print('two')
impor['m_custom']=impor['custom_fields'].apply(lambda x: re_extract(trip,str(x)))
print('three')
im=impor[(impor['m_name'].astype(str)!='[]')|(impor['m_desc'].astype(str)!='[]')|(impor['m_custom'].astype(str)!='[]')]
print(len(im))

# %%
print(len(im))
im[['external_id','m_name','m_desc','m_custom']][0:500]

# %%
imported['Q:origin']=''
match_na_re_curates=imported[['external_id','Q:origin']]

def get_df_name(df):
    name =[x for x in globals() if globals()[x] is df][0]
    return name
def looks_good(customer, matches): 
    drive_path = f'G:/Shared drives/GroupBy Public/Customer Success/.Enrich/Platform Upload Trail/{customer}/_Ready For Upload' 
    matches.to_csv(f'{drive_path}/Bed Bath & Beyond --{get_df_name(matches)}-match_na_re_curates{today}.csv',index=False) 
looks_good('Bed Bath & Beyond',match_na_re_curates)

# %%
na=dfs[(dfs['attribute'].astype(str)=='nan')|(dfs['attribute'].astype(str)=='None')]
print(len(na))
# Out:
# 0

# %%
customer_id = '5'
customer_name='%bedbathandbeyond%'
dateszs='2022-08-11'
attribut='size'
params = {'customer_id': customer_id,
          'customer_name':customer_name,
         'dateszs':dateszs,
         'attribute':attribut}
print('start')
dfs = query_from_file(file_name='../query/curated_all_attributes_date_one_attribute.sql', params=params)
print('continuing')
dfs=dfs[dfs['resolution'].astype(str)!='rules']
print('dfs')
dfz=dfs[dfs['custom_fields'].astype(str)!='None']
# dfz=dfz[dfz['buckets'].astype(str)=='Conduit Fittings, Replacement Parts, & Accessories']
print('customs')
custom_field_df=pd.json_normalize(dfz['custom_fields'])
df=pd.concat([dfz.drop('custom_fields', axis=1), custom_field_df], axis = 1)
print(len(df))
# Out:
# start
# continuing
# dfs
# customs
# 28322

# %%
material=df[['attribute','buckets','value','external_id','product_name','long_desc','LONG_DESCRIPTION','gbi_exp_product_type','gbi_syn_product_type','gbi_syn_size','gbi_product_type_affinity','Fill_Material','s_f_Fill_Material','s_f_binFill_Material']]
print(len(material))
# Out:
# 85030

# %%
trips="(?i)(duvet)|()"
material['d']=material['gbi_exp_product_type'].apply(lambda x: re_extract(trips,str(x)))
material['u']=material['gbi_syn_product_type'].apply(lambda x: re_extract(trips,str(x)))
material['v']=material['gbi_syn_size'].apply(lambda x: re_extract(trips,str(x)))
material['match']=material['long_desc'].apply(lambda x: re_extract(trips,str(x)))
material['matches']=material['LONG_DESCRIPTION'].apply(lambda x: re_extract(trips,str(x)))


duvet=material[(material['d'].astype(str)!='[]')|(material['u'].astype(str)!='[]')|(material['v'].astype(str)!='[]')|(material['match'].astype(str)!='[]')|(material['matches'].astype(str)!='[]')]
print(len(duvet))
print(duvet['buckets'].explode().value_counts().reset_index()['index'].to_list())
# Out:
# 1280
# ['Bedding Variety Packs', 'Duvet Covers', 'Vacuum/Water Bottles & Travel Mugs', 'Trays & Boards', 'Blankets/Throws', 'Comforters', 'Trees, Shrubs, Topiaries, & Other Plants', 'Throw/Decorative Pillows', 'Bed Skirts/Valances', 'Storage Bags', 'Curtains']

# %%
del duvet['d']
del duvet['u']
del duvet['v']
# del duvet['e']

# %%
fill=duvet[(duvet['external_id'].astype(str)!='nan')&((duvet['Fill_Material'].astype(str)!='nan')|(duvet['s_f_Fill_Material'].astype(str)!='nan')|(duvet['s_f_binFill_Material'].astype(str)!='nan'))]

# %%
trips="(?i)(.{0,10}fill.?material.{0,10})|()"
duvet['fill']=duvet['long_desc'].apply(lambda x: re_extract(trips,str(x)))
duvet['fills']=duvet['LONG_DESCRIPTION'].apply(lambda x: re_extract(trips,str(x)))
x=duvet[(duvet['fill'].astype(str)!='[]')|(duvet['fills'].astype(str)!='[]')]

# %%
x
# Out:
# Empty DataFrame
# Columns: [attribute, buckets, value, external_id, product_name, long_desc, LONG_DESCRIPTION, gbi_exp_product_type, gbi_syn_product_type, gbi_syn_size, gbi_product_type_affinity, Fill_Material, s_f_Fill_Material, s_f_binFill_Material, d, u, v, match, matches, fill, fills]
# Index: []

# %%
trips="(?i)(.{0,10}(?:duvet).{0,10})|()"
mat['match']=mat['long_desc'].apply(lambda x: re_extract(trips,str(x)))
mat['matches']=mat['product_name'].apply(lambda x: re_extract(trips,str(x)))
duvet=mat[(mat['match'].astype(str)!='[]')|(mat['matches'].astype(str)!='[]')]
duvet=duvet[duvet['value'].astype(str)=='n/a']
print(len(duvet))
# Out:
# 4

# %%
# customer_id = '5'
# customer_name='%bedbathandbeyond%'
# dateszs='2022-08-11'
# params = {'customer_id': customer_id,
#           'customer_name':customer_name,
#          'dateszs':dateszs}
# print('start')
# dfs = query_from_file(file_name='../query/curated_all_attributes_date.sql', params=params)
# print('continuing')
# dfs=dfs[dfs['resolution'].astype(str)!='rules']
# print('dfs')
# dfz=dfs[dfs['custom_fields'].astype(str)!='None']
# # dfz=dfz[dfz['buckets'].astype(str)=='Conduit Fittings, Replacement Parts, & Accessories']
# print('customs')
# custom_field_df=pd.json_normalize(dfz['custom_fields'])
# # dfz=dfs[dfs['custom_fields'].astype(str)!='None']
# # # dfz=dfz[dfz['buckets'].astype(str)=='Conduit Fittings, Replacement Parts, & Accessories']
# # custom_field_df=pd.json_normalize(dfz['custom_fields'])
# # fields = ['Set_Size']
# # df = pd.concat([dfz.drop('custom_fields', axis=1), custom_field_df[fields]], axis = 1)
# # print(len(df))

# %%
trips="(?i)(.{0,10}(?:comforter|duvet|sheets).{0,10})|()"
df['match']=df['long_desc'].apply(lambda x: re_extract(trips,str(x)))
df['matches']=df['product_name'].apply(lambda x: re_extract(trips,str(x)))
duvet=df[(df['match'].astype(str)!='[]')|(df['matches'].astype(str)!='[]')]

# %%
print(len(duvet))
duvet_na=duvet[duvet['value'].astype(str)=='n/a']
print(len(duvet_na))
# Out:
# 844
# 121

# %%
x=duvet_na[(duvet_na['Fill_Material'].astype(str)!='nan')|(duvet_na['s_f_Fill_Material'].astype(str)!='nan')|(duvet_na['s_f_binFill_Material'].astype(str)!='nan')|(duvet_na['s_f_binMaterial'].astype(str)!='nan')]
print(len(x))
x
# Out:
# 0
# Empty DataFrame
# Columns: [attribute, buckets, bucket_id, value, customer_name, external_id, product_name, long_desc, curated_date, resolution, curation_tasks.curated_by, Fill_Material, s_f_Fill_Material, s_f_binFill_Material, s_f_binMaterial, match, matches]
# Index: []

# %%
fields = ['Fill_Material','s_f_Fill_Material','s_f_binFill_Material','s_f_binMaterial']
df = pd.concat([dfz.drop('custom_fields', axis=1), custom_field_df[fields]], axis = 1)
print(len(df))
# Out:
# 58501

# %%
fill=df[(df['Fill_Material'].astype(str)!='nan')&(df['s_f_Fill_Material'].astype(str)=='nan')&(df['s_f_binFill_Material'].astype(str)=='nan')&(df['s_f_binMaterial'].astype(str)=='nan')]
print(len(fill))

fills=df[(df['Fill_Material'].astype(str)=='nan')&(df['s_f_Fill_Material'].astype(str)!='nan')&(df['s_f_binFill_Material'].astype(str)=='nan')&(df['s_f_binMaterial'].astype(str)=='nan')]
print(len(fills))

fillz=df[(df['Fill_Material'].astype(str)=='nan')&(df['s_f_Fill_Material'].astype(str)=='nan')&(df['s_f_binFill_Material'].astype(str)!='nan')&(df['s_f_binMaterial'].astype(str)=='nan')]
print(len(fillz))

filling=df[(df['Fill_Material'].astype(str)=='nan')&(df['s_f_Fill_Material'].astype(str)=='nan')&(df['s_f_binFill_Material'].astype(str)=='nan')&(df['s_f_binMaterial'].astype(str)!='nan')]
print(len(filling))
# Out:
# 0
# 2
# 0
# 626

# %%
# fillings=df[((df['Fill_Material'].astype(str)!='nan')|(df['s_f_Fill_Material'].astype(str)!='nan')|(df['s_f_binFill_Material'].astype(str)!='nan'))&(df['s_f_binMaterial'].astype(str)=='nan')&(df['external_id'].astype(str)!='nan')]
# print(len(fillings))
# fillings
# filling

# %%
# filling['buckets'].explode().value_counts()
# x=filling[filling['buckets'].astype(str)!='nan']
# print(len(x))
# x

# %%
trip=r'''(?i)(.{0,20}duvet.{0,20})|(.{0,20}fill.{0,20})|()'''                                                              
fill['matches']=fill['long_desc'].apply(lambda x: re_extract(trip,str(x)))
duvet=fill[fill['matches'].astype(str)!='[]']
duvet#[duvet['s_f_binMaterial'].astype(str)=='''['Cotton Blend']''']
print(len(duvet))

# %%
duvet[duvet['value'].astype(str)=='n/a']

# %%
fill_material=df[(df['attribute'].astype(str)=='fill_material')]

# %%
fill_materials=fill_material[(fill_material['Fill_Material'].astype(str)!='nan')|(fill_material['s_f_Fill_Material'].astype(str)!='nan')|(fill_material['s_f_binFill_Material'].astype(str)!='nan')|(fill_material['s_f_binMaterial'].astype(str)!='nan')|(fill_material['Fill_Material'].astype(str)!='nan')]
# del fill_materials ['buckets']
# del fill_materials ['bucket_id']
del fill_materials ['customer_name']
del fill_materials ['curated_date']
del fill_materials ['resolution']
del fill_materials ['curation_tasks.curated_by']

fill_materials#['value'].explode().value_counts()

trip=r'''(?i)(duvet)|()'''                                                              
fill_materials['matches']=fill_materials['product_name'].apply(lambda x: re_extract(trip,str(x)))
duvet=fill_materials[fill_materials['matches'].astype(str)!='[]']
duvet#[duvet['s_f_binMaterial'].astype(str)=='''['Cotton Blend']''']

duvets=duvet[(duvet['s_f_binMaterial'].astype(str)!='nan')&(duvet['s_f_binMaterial'].astype(str)!="['Other']")&(duvet['s_f_binMaterial'].astype(str)!="['Modal']")&(duvet['s_f_binMaterial'].astype(str)!="['Cotton Blend']")]
duvets['Q:fill_material']=duvets['s_f_binMaterial']

match_duvets=duvets[['external_id','Q:fill_material']]

def get_df_name(df):
    name =[x for x in globals() if globals()[x] is df][0]
    return name
def looks_good(customer, matches): 
    drive_path = f'G:/Shared drives/GroupBy Public/Customer Success/.Enrich/Platform Upload Trail/{customer}/_Ready For Upload' 
    matches.to_csv(f'{drive_path}/Bed Bath & Beyond --{get_df_name(matches)}-match_duvets{today}.csv',index=False) 
looks_good('Bed Bath & Beyond',match_duvets)
